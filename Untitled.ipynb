# %%
import pandas as pd
import functions
import os

# %%
ls=[]

for i in os.listdir(r'images\scrapping'):
    ls.append(i)

# %%
ls.pop(0)
# Out:
# '.ipynb_checkpoints'

# %%
ls
# Out:
# ['10008-o.jpg',
#  '1001-blank-parking-receipt.jpg',
#  '10010-W1siZiIsIjIwMTgvMTIvMDUvMTdfMzFfNDNfNDM4Xzc1MDE1X0xhX0NhbnRpbmVfZHVfVHJvcXVldC5wbmciXSxbInAiLCJ0aHVtYiIsIjMwMHgiXSxbImUiLCJqcGciLCItcXVhbGl0eSA1MSJdXQ.jpg',
#  '10011-4c8c378b8c36a44672d3be329ddd7a51.jpg',
#  '10013-photo0jpg.jpg',
#  '10014-o.jpg',
#  '10015-bill.jpg',
#  '10016-IMAG0860.jpg',
#  '10017-o.jpg',
#  '1002-6802935529_d119f593b7_z.jpg',
#  '1002-photo0jpg.jpg',
#  '1002-tumblr_l8fma4N53h1qctkcl.jpg',
#  '10020-o.jpg',
#  '10022-bjs-restaurant-brewhouse.jpg',
#  '10022-ls.jpg',
#  '10022-ta-img-20171210-200007.jpg',
#  '10023-the-caravel-restaurant.jpg',
#  '10026-H2g6E.jpg',
#  '1003-o.jpg',
#  '10034-bill.jpg',
#  '1005-348s.jpg',
#  '10056-RestaurantReceipt1_sm.jpg',
#  '1006-receipts.jpg',
#  '10063-Master.jpg',
#  '10064-25927930_2ROzaCbksjBDPHr78i8CZUQmngndRMGZ0WD0r6hdAHE.jpg',
#  '10064-scontrino.jpg',
#  '10066-o.jpg',
#  '10069-o.jpg',
#  '10070-photo0jpg.jpg',
#  '10077-348s.jpg',
# ...

# %%
import functions

# %%
help(functions)
# Out:
# Help on module functions:
#
# NAME
#     functions
#
# FUNCTIONS
#     clean_image(pathImage)
#
#     extract_data(text)
#
#     extract_text(url)
#
# FILE
#     c:\users\trell\onedrive\documentos\github\scotia-bank-reciept-processing-and-budget-forcasting\functions.py

# %%
def extract (url):
    image= functions.clean_image(url)
    text= functions.extract_text(image)
    data= functions.extract_data(text)
    return data

# %%
data=[]

for i in ls:
    d=extract(i)
    data.append(d)
    
df=pd.concat(data)
df
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [12], in <cell line: 3>()
#       1 data=[]
#       3 for i in ls:
# ----> 4     d=extract(i)
#       5     data.append(d)
#       7 df=pd.concat(data)
#
# Input In [7], in extract(url)
#       1 def extract (url):
# ----> 2     image= functions.clean_image(url)
#       3     text= functions.extract_text(image)
#       4     data= functions.extract_data(text)
#
# File ~\OneDrive\Documentos\GitHub\scotia-bank-reciept-processing-and-budget-forcasting\functions.py:110, in clean_image(pathImage)
#     107 #pathImage = r"images/large-receipt-image-dataset-SRD/1013-receipt.jpg"
#     109 img = cv2.imread(pathImage)
# --> 110 img = cv2.resize(img, (widthImg, heightImg)) # RESIZE IMAGE
#     111 imgBlank = np.zeros((heightImg,widthImg, 3), np.uint8) # CREATE A BLANK IMAGE FOR TESTING DEBUGING IF  REQUIRED
# ...
