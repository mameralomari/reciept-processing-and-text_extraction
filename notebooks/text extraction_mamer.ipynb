# %%
#reqs
#!pip install commonregex
#!pip install pytesseract 
#!pip install opencv 
#!pip install numpy 
#!pip install pillow
#!pip install pgeocode
#!pip install pandas 
#!pip install

# %%
import pytesseract 
from PIL import Image, ImageOps
import numpy as np
# from postal.parser import parse_address

# %%
def extract_text(url):
    import pytesseract 
    from PIL import Image
    
    """extracts test out of image
    --inputs= image_url """
    #opening the image
    im=Image.open(url)
    grey= im.convert(mode="L")
    threshold= 160
    image=grey.point(lambda x: 255 if x > threshold else 0)
    
    #configuration for pytesseract to operate with text extraction
    config = ('-l eng --oem 1 --psm 3')
    text = pytesseract.image_to_string(image, config=config)
    
    return text

# %%
image=(r"images/large-receipt-image-dataset-SRD/1012-receipt.jpg")
text=extract_text(image)
print (text)
# Out:
# #14
#
# HP Pho Ga
# 8930 Mission Dr. #102
# pp ooee 91770
# Phone (626)268-9999
#
#
#
#
# bate: Apr 01, 2019 Time; 05:
#
# Server: Admin
#
# Bill; 59980 Table : 14
#
# 1 Pho Ga (Small) 8.00
#
# 1 Pho Ga (Large) 9.00
#
# 1 Gor Cuon 5.25
# “Subtotal 22.25
# TAX 211
# Total 24.36
# 8. Service Gharge- 40% 8.90
#
# Total $33 26
#
# Suggested Tip : 15% (3,65)
#
# 18% (4.38)
#
# 20% (4.87)
# Open Time : Apr 01, 2019 04:39PM
# Printed By : Admin
#
# Thank you for Coming !

# %% [markdown]
# # Image cleaning and cropping function
# -- this function performs the following transformations
#
# ---- resize to 640,480
# n\
# ---- BGR to grey
# n\
# ---- Apply GaussianBlur (5,5),1
# n\
# ---- Uses adaptive threshold (guissan Binary)
# n\
# ---- dialate the image
# n\
# ---- erode
# n\
# ---- find contours
# n\
# ---- apply contours
# n\
# ---- crop image based and contours and save them

# %%
def clean_image(pathImage):
    import cv2
    import numpy as np
    import utlis

    #cap.set(10,160)
    heightImg = 1920
    widthImg  = 1080

    
    #pathImage = r"images/large-receipt-image-dataset-SRD/1013-receipt.jpg"

    img = cv2.imread(pathImage)
    img = cv2.resize(img, (widthImg, heightImg)) # RESIZE IMAGE
    imgBlank = np.zeros((heightImg,widthImg, 3), np.uint8) # CREATE A BLANK IMAGE FOR TESTING DEBUGING IF REQUIRED
    imgGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # CONVERT IMAGE TO GRAY SCALE
    imgBlur = cv2.GaussianBlur(imgGray, (5, 5), 1) # ADD GAUSSIAN BLUR
    #thres=utlis.valTrackbars() # GET TRACK BAR VALUES FOR THRESHOLDS
    imgThreshold = cv2.adaptiveThreshold(imgBlur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
                cv2.THRESH_BINARY,11,2) # APPLY CANNY BLUR
    kernel = np.ones((5, 5))
    imgDial = cv2.dilate(imgThreshold, kernel, iterations=2) # APPLY DILATION
    imgThreshold = cv2.erode(imgDial, kernel, iterations=1)  # APPLY EROSION

        ## FIND ALL COUNTOURS
    imgContours = img.copy() # COPY IMAGE FOR DISPLAY PURPOSES
    imgBigContour = img.copy() # COPY IMAGE FOR DISPLAY PURPOSES
    contours, hierarchy = cv2.findContours(imgThreshold, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE) # FIND ALL CONTOURS
    cv2.drawContours(imgContours, contours, -1, (0, 255, 0), 10) # DRAW ALL DETECTED CONTOURS


        # FIND THE BIGGEST COUNTOUR
    biggest, maxArea = utlis.biggestContour(contours) # FIND THE BIGGEST CONTOUR
    if biggest.size != 0:
            biggest=utlis.reorder(biggest)
            cv2.drawContours(imgBigContour, biggest, -1, (0, 255, 0), 20) # DRAW THE BIGGEST CONTOUR
            imgBigContour = utlis.drawRectangle(imgBigContour,biggest,2)
            pts1 = np.float32(biggest) # PREPARE POINTS FOR WARP
            pts2 = np.float32([[0, 0],[widthImg, 0], [0, heightImg],[widthImg, heightImg]]) # PREPARE POINTS FOR WARP
            matrix = cv2.getPerspectiveTransform(pts1, pts2)
            imgWarpColored = cv2.warpPerspective(img, matrix, (widthImg, heightImg))

            #REMOVE 20 PIXELS FORM EACH SIDE
            imgWarpColored=imgWarpColored[20:imgWarpColored.shape[0] - 20, 20:imgWarpColored.shape[1] - 20]
            imgWarpColored = cv2.resize(imgWarpColored,(widthImg,heightImg))
           
    count=1
    cv2.imwrite("Scanned/myImage"+str(count)+".jpg",imgWarpColored)
    item_name=("Scanned/myImage"+str(count)+".jpg")
    return item_name

# %%
item=clean_image(r"images/large-receipt-image-dataset-SRD/1084-receipt.jpg")
import functions 
print (functions.extract_text(item))
# Out:
# Trattoria Sort
#
# 328 Washingtonstreet
# Hoboken, Nd
# 201-533-1801
#
# TABLE # 4
# CHECK# 27273
#
# ae ae 9:93:48 PM
# e
#
# SERVER: Gaston
# STATION: 01
#
# Item Count: 4
#
# 1 STUFFED nee
#
# 1 BK FETT AL PORCINI *
# 1 COSTOLETTE/ALLA/PAP#
# 1 BROCCOLI RABE W/ GAM
#
# | ESPRESSO
# 1 DBLD ESPRESSO
#
# Sot
# GRAND TOT
#
# Opened: 7/1/2018 5:53:48 PM
#
# $117.7
# 8,24
#
# "
# ‘10.

# %%
import functions

# %%
import os 
ls=[]
url=r"images/"
for filename in os.listdir(url):
    f = os.path.join(url, filename)
   
    ls.append(f)

# %%
for i in df.columns:
    print("The VALUES of "+ i + str(df1[i].isna().value_counts()))
# Out:
# The VALUES of ZipcodeFalse    105
# True      95
# Name: Zipcode, dtype: int64
# The VALUES of LatitudeTrue     139
# False     61
# Name: Latitude, dtype: int64
# The VALUES of LongitudeTrue     139
# False     61
# Name: Longitude, dtype: int64
# The VALUES of AddressTrue     152
# False     48
# Name: Address, dtype: int64
# The VALUES of pricesTrue     137
# False     63
# Name: prices, dtype: int64
# The VALUES of timeTrue     126
# False     74
# Name: time, dtype: int64

# %%
df.to_csv("data\imporved_data_structured.csv")

# %%
import matplotlib.pyplot as plt

# %%
df.isna().sum().plot(kind = 'bar')
plt.title(" isna on dataset with otsu thresholding")
# Out:
# Text(0.5, 1.0, ' isna on dataset with otsu thresholding')

# %%
print(texts[23])
# Out:
# Tha
#
# GUSTO
#
# Thai Gusto Restaurant
# 2011 Hewitt Ave
# Everett WA 98201
# Tei. 425-252-3525 Fax. 425-252-3525
#
# Helcome to Thai Gusto
#
#
#
#
#
# Table 4
# Date: 6/16/2017 12:36 PM
# Server: PRACH (TY
# Chang (26$3.50) $7.00
# $19.24
#
# #114 Garlic Delight
# [Chicken] (5e¥##81 [Smal] Browr: Rice!
# $10
#
# 4128 Red Curry
# [Chicken] [5##+#*] [Sma'i Brown Rice]
#
# Tota] 4 item(s)
#
# Sales Tax
#
# Grand Total $20.15
#
# Tip Guide
# r6y=64.52, 184=85.43, 2048.03
#
# Thank you very much.
# Come back aga)”.
#
# ~ GUEST crete -
# This is not a “ere ce.

# %%
with open(r'data/newtext2oem3psm6.txt', 'w',encoding="utf-8") as fp:
    for item in texts:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
df1.isna().sum().plot(kind = 'bar')
plt.title(" isna on dataset with otsu thresholding and noise clearance ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 2>()
#       1 df1.isna().sum().plot(kind = 'bar')
# ----> 2 plt.title(" isna on dataset with otsu thresholding and noise clearance ")
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd 
import os 
import functions

texts=[]
counter=0

    
dfl=[]

for i in ls1 :
    for s in i:
    #text=functions.extract_from_image(i)
        image=functions.clean_image(s)
        text=functions.extract_text(image)
        texts.append(text)
        counter+=1
        print ("extracted_test " + str(counter))
        df=functions.extract_data(text)
        dfl.append(df)

# %%
df2=pd.concat(dfl)       
df2

# %%
df2.isna().sum().plot(kind = 'bar')
plt.title(" isna on dataset as is ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 df2.isna().sum().plot(kind = 'bar')
# ----> 2 plt.title(" isna on dataset as is ")
#
# NameError: name 'plt' is not defined

# %%
for i in df2.columns:
    print("The VALUES of "+ i + str(df2[i].isna().value_counts()))
# Out:
# The VALUES of ZipcodeFalse    141
# True      59
# Name: Zipcode, dtype: int64
# The VALUES of LatitudeTrue     112
# False     88
# Name: Latitude, dtype: int64
# The VALUES of LongitudeTrue     112
# False     88
# Name: Longitude, dtype: int64
# The VALUES of AddressTrue     131
# False     69
# Name: Address, dtype: int64
# The VALUES of pricesTrue     127
# False     73
# Name: prices, dtype: int64
# The VALUES of timeFalse    100
# True     100
# Name: time, dtype: int64

# %%
import os 
ls=[]
url= r"n/"
for filename in os.listdir(url):
    f = os.path.join(url, filename)
   
    ls.append(f)

# %%
len(ls)
# Out:
# 7245

# %%
l=[]
counter=0
for i in range(len(ls)//100):
    
    l.append(ls[counter:counter+100])
    #l.append(lss)
    
    counter+=100

# %%
import pandas as pd 
import os 
import functions
from time import sleep
texts_list=[]
counter=0
fails = []
    
dfl=[]
counter = 0
batch = 0
for i in l[0:] :
    for s in i:
    #text=functions.extract_from_image(i)
            print('Attempting:', s)

            try: 
                image=functions.clean_image(s)

                text=functions.extract_text(image)
                texts_list.append(text)
                counter+=1
                print ("extracted_test " + str(counter))
                df=functions.extract_data(text)
                dfl.append(df)
                
            except:
                print('failed to extract:',s)
                fails.append(s)
    with open(r'data/textcollection.txt', 'w',encoding="utf-8") as fp:
        for item in texts:
            # write each item on a new line
            fp.write("%s\n" % item)
        print('batch number:', batch)
        batch+=1
# Out:
# Attempting: n/1.jpg
# extracted_test 1
# Attempting: n/10.jpg
# extracted_test 2
# Attempting: n/100.jpg
# extracted_test 3
# Attempting: n/1000.jpg
# extracted_test 4
# Attempting: n/1001.jpg
# extracted_test 5
# Attempting: n/1002.jpg
# extracted_test 6
# Attempting: n/1003.jpg
# extracted_test 7
# Attempting: n/1004.jpg
# extracted_test 8
# Attempting: n/1005.jpg
# extracted_test 9
# Attempting: n/1006.jpg
# extracted_test 10
# Attempting: n/1007.jpg
# extracted_test 11
# Attempting: n/1008.jpg
# extracted_test 12
# Attempting: n/1009.jpg
# extracted_test 13
# Attempting: n/101.jpg
# extracted_test 14
# Attempting: n/1010.jpg
# extracted_test 15
# Attempting: n/1011.jpg
# extracted_test 16
# Attempting: n/1012.jpg
# extracted_test 17
# Attempting: n/1013.jpg
# extracted_test 18
# Attempting: n/1014.jpg
# extracted_test 19
# Attempting: n/1015.jpg
# extracted_test 20
# Attempting: n/1016.jpg
# extracted_test 21
# Attempting: n/1017.jpg
# extracted_test 22
# Attempting: n/1018.jpg
# extracted_test 23
# Attempting: n/1019.jpg
# extracted_test 24
# Attempting: n/102.jpg
# extracted_test 25
# Attempting: n/1020.jpg
# extracted_test 26
# Attempting: n/1021.jpg
# extracted_test 27
# Attempting: n/1022.jpg
# extracted_test 28
# Attempting: n/1023.jpg
# extracted_test 29
# Attempting: n/1024.jpg
# extracted_test 30
# Attempting: n/1025.jpg
# extracted_test 31
# Attempting: n/1026.jpg
# extracted_test 32
# Attempting: n/1027.jpg
# extracted_test 33
# Attempting: n/1028.jpg
# extracted_test 34
# Attempting: n/1029.jpg
# extracted_test 35
# Attempting: n/103.jpg
# extracted_test 36
# Attempting: n/1030.jpg
# extracted_test 37
# Attempting: n/1031.jpg
# extracted_test 38
# Attempting: n/1032.jpg
# extracted_test 39
# Attempting: n/1033.jpg
# extracted_test 40
# Attempting: n/1034.jpg
# extracted_test 41
# Attempting: n/1035.jpg
# extracted_test 42
# Attempting: n/1036.jpg
# extracted_test 43
# Attempting: n/1037.jpg
# extracted_test 44
# Attempting: n/1038.jpg
# extracted_test 45
# Attempting: n/1039.jpg
# extracted_test 46
# Attempting: n/104.jpg
# extracted_test 47
# Attempting: n/1040.jpg
# extracted_test 48
# Attempting: n/1041.jpg
# extracted_test 49
# Attempting: n/1042.jpg
# extracted_test 50
# Attempting: n/1043.jpg
# extracted_test 51
# Attempting: n/1044.jpg
# extracted_test 52
# Attempting: n/1045.jpg
# extracted_test 53
# Attempting: n/1046.jpg
# extracted_test 54
# Attempting: n/1047.jpg
# extracted_test 55
# Attempting: n/1048.jpg
# extracted_test 56
# Attempting: n/1049.jpg
# extracted_test 57
# Attempting: n/105.jpg
# extracted_test 58
# Attempting: n/1050.jpg
# extracted_test 59
# Attempting: n/1051.jpg
# extracted_test 60
# Attempting: n/1052.jpg
# extracted_test 61
# Attempting: n/1053.jpg
# extracted_test 62
# Attempting: n/1054.jpg
# extracted_test 63
# Attempting: n/1055.jpg
# extracted_test 64
# Attempting: n/1056.jpg
# extracted_test 65
# Attempting: n/1057.jpg
# extracted_test 66
# Attempting: n/1058.jpg
# extracted_test 67
# Attempting: n/1059.jpg
# extracted_test 68
# Attempting: n/106.jpg
# extracted_test 69
# Attempting: n/1060.jpg
# extracted_test 70
# Attempting: n/1061.jpg
# extracted_test 71
# Attempting: n/1062.jpg
# extracted_test 72
# Attempting: n/1063.jpg
# extracted_test 73
# Attempting: n/1064.jpg
# extracted_test 74
# Attempting: n/1065.jpg
# extracted_test 75
# Attempting: n/1066.jpg
# extracted_test 76
# Attempting: n/1067.jpg
# extracted_test 77
# Attempting: n/1068.jpg
# extracted_test 78
# Attempting: n/1069.jpg
# extracted_test 79
# Attempting: n/107.jpg
# extracted_test 80
# Attempting: n/1070.jpg
# extracted_test 81
# Attempting: n/1071.jpg
# extracted_test 82
# Attempting: n/1072.jpg
# extracted_test 83
# Attempting: n/1073.jpg
# extracted_test 84
# Attempting: n/1074.jpg
# extracted_test 85
# Attempting: n/1075.jpg
# extracted_test 86
# Attempting: n/1076.jpg
# extracted_test 87
# Attempting: n/1077.jpg
# extracted_test 88
# Attempting: n/1078.jpg
# extracted_test 89
# Attempting: n/1079.jpg
# extracted_test 90
# Attempting: n/108.jpg
# extracted_test 91
# Attempting: n/1080.jpg
# extracted_test 92
# Attempting: n/1081.jpg
# extracted_test 93
# Attempting: n/1082.jpg
# extracted_test 94
# Attempting: n/1083.jpg
# extracted_test 95
# Attempting: n/1084.jpg
# extracted_test 96
# Attempting: n/1085.jpg
# extracted_test 97
# Attempting: n/1086.jpg
# extracted_test 98
# Attempting: n/1087.jpg
# extracted_test 99
# Attempting: n/1088.jpg
# extracted_test 100
# Attempting: n/1089.jpg
# extracted_test 101
# Attempting: n/109.jpg
# extracted_test 102
# Attempting: n/1090.jpg
# extracted_test 103
# Attempting: n/1091.jpg
# extracted_test 104
# Attempting: n/1092.jpg
# extracted_test 105
# Attempting: n/1093.jpg
# extracted_test 106
# Attempting: n/1094.jpg
# extracted_test 107
# Attempting: n/1095.jpg
# extracted_test 108
# Attempting: n/1096.jpg
# extracted_test 109
# Attempting: n/1097.jpg
# extracted_test 110
# Attempting: n/1098.jpg
# extracted_test 111
# Attempting: n/1099.jpg
# extracted_test 112
# Attempting: n/11.jpg
# extracted_test 113
# Attempting: n/110.jpg
# extracted_test 114
# Attempting: n/1100.jpg
# extracted_test 115
# Attempting: n/1101.jpg
# extracted_test 116
# Attempting: n/1102.jpg
# extracted_test 117
# Attempting: n/1103.jpg
# extracted_test 118
# Attempting: n/1104.jpg
# extracted_test 119
# Attempting: n/1105.jpg
# extracted_test 120
# Attempting: n/1106.jpg
# extracted_test 121
# Attempting: n/1107.jpg
# extracted_test 122
# Attempting: n/1108.jpg
# extracted_test 123
# Attempting: n/1109.jpg
# extracted_test 124
# Attempting: n/111.jpg
# extracted_test 125
# Attempting: n/1110.jpg
# extracted_test 126
# Attempting: n/1111.jpg
# extracted_test 127
# Attempting: n/1112.jpg
# extracted_test 128
# Attempting: n/1113.jpg
# extracted_test 129
# Attempting: n/1114.jpg
# extracted_test 130
# Attempting: n/1115.jpg
# extracted_test 131
# Attempting: n/1116.jpg
# extracted_test 132
# Attempting: n/1117.jpg
# extracted_test 133
# Attempting: n/1118.jpg
# extracted_test 134
# Attempting: n/1119.jpg
# extracted_test 135
# Attempting: n/112.jpg
# extracted_test 136
# Attempting: n/1120.jpg
# extracted_test 137
# Attempting: n/1121.jpg
# extracted_test 138
# Attempting: n/1122.jpg
# extracted_test 139
# Attempting: n/1123.jpg
# extracted_test 140
# Attempting: n/1124.jpg
# extracted_test 141
# Attempting: n/1125.jpg
# extracted_test 142
# Attempting: n/1126.jpg
# extracted_test 143
# Attempting: n/1127.jpg
# extracted_test 144
# Attempting: n/1128.jpg
# extracted_test 145
# Attempting: n/1129.jpg
# extracted_test 146
# Attempting: n/113.jpg
# extracted_test 147
# Attempting: n/1130.jpg
# extracted_test 148
# Attempting: n/1131.jpg
# extracted_test 149
# Attempting: n/1132.jpg
# extracted_test 150
# Attempting: n/1133.jpg
# extracted_test 151
# Attempting: n/1134.jpg
# extracted_test 152
# Attempting: n/1135.jpg
# extracted_test 153
# Attempting: n/1136.jpg
# extracted_test 154
# Attempting: n/1137.jpg
# extracted_test 155
# Attempting: n/1138.jpg
# extracted_test 156
# Attempting: n/1139.jpg
# extracted_test 157
# Attempting: n/114.jpg
# extracted_test 158
# Attempting: n/1140.jpg
# extracted_test 159
# Attempting: n/1141.jpg
# extracted_test 160
# Attempting: n/1142.jpg
# extracted_test 161
# Attempting: n/1143.jpg
# extracted_test 162
# Attempting: n/1144.jpg
# extracted_test 163
# Attempting: n/1145.jpg
# extracted_test 164
# Attempting: n/1146.jpg
# extracted_test 165
# Attempting: n/1147.jpg
# extracted_test 166
# Attempting: n/1148.jpg
# extracted_test 167
# Attempting: n/1149.jpg
# extracted_test 168
# Attempting: n/115.jpg
# extracted_test 169
# Attempting: n/1150.jpg
# extracted_test 170
# Attempting: n/1151.jpg
# extracted_test 171
# Attempting: n/1152.jpg
# extracted_test 172
# Attempting: n/1153.jpg
# extracted_test 173
# Attempting: n/1154.jpg
# extracted_test 174
# Attempting: n/1155.jpg
# extracted_test 175
# Attempting: n/1156.jpg
# extracted_test 176
# Attempting: n/1157.jpg
# extracted_test 177
# Attempting: n/1158.jpg
# extracted_test 178
# Attempting: n/1159.jpg
# extracted_test 179
# Attempting: n/116.jpg
# extracted_test 180
# Attempting: n/1160.jpg
# extracted_test 181
# Attempting: n/1161.jpg
# extracted_test 182
# Attempting: n/1162.jpg
# extracted_test 183
# Attempting: n/1163.jpg
# extracted_test 184
# Attempting: n/1164.jpg
# extracted_test 185
# Attempting: n/1165.jpg
# extracted_test 186
# Attempting: n/1166.jpg
# extracted_test 187
# Attempting: n/1167.jpg
# extracted_test 188
# Attempting: n/1168.jpg
# extracted_test 189
# Attempting: n/1169.jpg
# extracted_test 190
# Attempting: n/117.jpg
# extracted_test 191
# Attempting: n/1170.jpg
# extracted_test 192
# Attempting: n/1171.jpg
# extracted_test 193
# Attempting: n/1172.jpg
# extracted_test 194
# Attempting: n/1173.jpg
# extracted_test 195
# Attempting: n/1174.jpg
# extracted_test 196
# Attempting: n/1175.jpg
# extracted_test 197
# Attempting: n/1176.jpg
# extracted_test 198
# Attempting: n/1177.jpg
# extracted_test 199
# Attempting: n/1178.jpg
# extracted_test 200
# Attempting: n/1179.jpg
# extracted_test 201
# Attempting: n/118.jpg
# extracted_test 202
# Attempting: n/1180.jpg
# extracted_test 203
# Attempting: n/1181.jpg
# extracted_test 204
# Attempting: n/1182.jpg
# extracted_test 205
# Attempting: n/1183.jpg
# extracted_test 206
# Attempting: n/1184.jpg
# extracted_test 207
# Attempting: n/1185.jpg
# extracted_test 208
# Attempting: n/1186.jpg
# extracted_test 209
# Attempting: n/1187.jpg
# extracted_test 210
# Attempting: n/1188.jpg
# extracted_test 211
# Attempting: n/1189.jpg
# extracted_test 212
# Attempting: n/119.jpg
# extracted_test 213
# Attempting: n/1190.jpg
# extracted_test 214
# Attempting: n/1191.jpg
# extracted_test 215
# Attempting: n/1192.jpg
# extracted_test 216
# Attempting: n/1193.jpg
# extracted_test 217
# Attempting: n/1194.jpg
# extracted_test 218
# Attempting: n/1195.jpg
# extracted_test 219
# Attempting: n/1196.jpg
# extracted_test 220
# Attempting: n/1197.jpg
# extracted_test 221
# Attempting: n/1198.jpg
# extracted_test 222
# Attempting: n/1199.jpg
# extracted_test 223
# Attempting: n/12.jpg
# extracted_test 224
# Attempting: n/120.jpg
# extracted_test 225
# Attempting: n/1200.jpg
# extracted_test 226
# Attempting: n/1201.jpg
# extracted_test 227
# Attempting: n/1202.jpg
# extracted_test 228
# Attempting: n/1203.jpg
# extracted_test 229
# Attempting: n/1204.jpg
# extracted_test 230
# Attempting: n/1205.jpg
# extracted_test 231
# Attempting: n/1206.jpg
# extracted_test 232
# Attempting: n/1207.jpg
# extracted_test 233
# Attempting: n/1208.jpg
# extracted_test 234
# Attempting: n/1209.jpg
# extracted_test 235
# Attempting: n/121.jpg
# extracted_test 236
# Attempting: n/1210.jpg
# extracted_test 237
# Attempting: n/1211.jpg
# extracted_test 238
# Attempting: n/1212.jpg
# extracted_test 239
# Attempting: n/1213.jpg
# extracted_test 240
# Attempting: n/1214.jpg
# extracted_test 241
# Attempting: n/1215.jpg
# extracted_test 242
# Attempting: n/1216.jpg
# extracted_test 243
# Attempting: n/1217.jpg
# failed to extract: n/1217.jpg
# Attempting: n/1218.jpg
# extracted_test 244
# Attempting: n/1219.jpg
# extracted_test 245
# Attempting: n/122.jpg
# extracted_test 246
# Attempting: n/1220.jpg
# extracted_test 247
# Attempting: n/1221.jpg
# extracted_test 248
# Attempting: n/1222.jpg
# extracted_test 249
# Attempting: n/1223.jpg
# extracted_test 250
# Attempting: n/1224.jpg
# extracted_test 251
# Attempting: n/1225.jpg
# extracted_test 252
# Attempting: n/1226.jpg
# extracted_test 253
# Attempting: n/1227.jpg
# extracted_test 254
# Attempting: n/1228.jpg
# extracted_test 255
# Attempting: n/1229.jpg
# extracted_test 256
# Attempting: n/123.jpg
# extracted_test 257
# Attempting: n/1230.jpg
# extracted_test 258
# Attempting: n/1231.jpg
# extracted_test 259
# Attempting: n/1232.jpg
# extracted_test 260
# Attempting: n/1233.jpg
# extracted_test 261
# Attempting: n/1234.jpg
# extracted_test 262
# Attempting: n/1235.jpg
# extracted_test 263
# Attempting: n/1236.jpg
# extracted_test 264
# Attempting: n/1237.jpg
# extracted_test 265
# Attempting: n/1238.jpg
# extracted_test 266
# Attempting: n/1239.jpg
# extracted_test 267
# Attempting: n/124.jpg
# extracted_test 268
# Attempting: n/1240.jpg
# extracted_test 269
# Attempting: n/1241.jpg
# extracted_test 270
# Attempting: n/1242.jpg
# extracted_test 271
# Attempting: n/1243.jpg
# extracted_test 272
# Attempting: n/1244.jpg
# extracted_test 273
# Attempting: n/1245.jpg
# extracted_test 274
# Attempting: n/1246.jpg
# extracted_test 275
# Attempting: n/1247.jpg
# extracted_test 276
# Attempting: n/1248.jpg
# extracted_test 277
# Attempting: n/1249.jpg
# extracted_test 278
# Attempting: n/125.jpg
# extracted_test 279
# Attempting: n/1250.jpg
# extracted_test 280
# Attempting: n/1251.jpg
# extracted_test 281
# Attempting: n/1252.jpg
# extracted_test 282
# Attempting: n/1253.jpg
# extracted_test 283
# Attempting: n/1254.jpg
# extracted_test 284
# Attempting: n/1255.jpg
# extracted_test 285
# Attempting: n/1256.jpg
# extracted_test 286
# Attempting: n/1257.jpg
# extracted_test 287
# Attempting: n/1258.jpg
# extracted_test 288
# Attempting: n/1259.jpg
# extracted_test 289
# Attempting: n/126.jpg
# extracted_test 290
# Attempting: n/1260.jpg
# extracted_test 291
# Attempting: n/1261.jpg
# extracted_test 292
# Attempting: n/1262.jpg
# extracted_test 293
# Attempting: n/1263.jpg
# extracted_test 294
# Attempting: n/1264.jpg
# extracted_test 295
# Attempting: n/1265.jpg
# extracted_test 296
# Attempting: n/1266.jpg
# extracted_test 297
# Attempting: n/1267.jpg
# extracted_test 298
# Attempting: n/1268.jpg
# extracted_test 299
# Attempting: n/1269.jpg
# extracted_test 300
# Attempting: n/127.jpg
# extracted_test 301
# Attempting: n/1270.jpg
# extracted_test 302
# Attempting: n/1271.jpg
# extracted_test 303
# Attempting: n/1272.jpg
# extracted_test 304
# Attempting: n/1273.jpg
# extracted_test 305
# Attempting: n/1274.jpg
# extracted_test 306
# Attempting: n/1275.jpg
# extracted_test 307
# Attempting: n/1276.jpg
# extracted_test 308
# Attempting: n/1277.jpg
# extracted_test 309
# Attempting: n/1278.jpg
# extracted_test 310
# Attempting: n/1279.jpg
# extracted_test 311
# Attempting: n/128.jpg
# extracted_test 312
# Attempting: n/1280.jpg
# extracted_test 313
# Attempting: n/1281.jpg
# extracted_test 314
# Attempting: n/1282.jpg
# extracted_test 315
# Attempting: n/1283.jpg
# extracted_test 316
# Attempting: n/1284.jpg
# extracted_test 317
# Attempting: n/1285.jpg
# extracted_test 318
# Attempting: n/1286.jpg
# extracted_test 319
# Attempting: n/1287.jpg
# extracted_test 320
# Attempting: n/1288.jpg
# extracted_test 321
# Attempting: n/1289.jpg
# extracted_test 322
# Attempting: n/129.jpg
# extracted_test 323
# Attempting: n/1290.jpg
# extracted_test 324
# Attempting: n/1291.jpg
# extracted_test 325
# Attempting: n/1292.jpg
# extracted_test 326
# Attempting: n/1293.jpg
# extracted_test 327
# Attempting: n/1294.jpg
# extracted_test 328
# Attempting: n/1295.jpg
# extracted_test 329
# Attempting: n/1296.jpg
# extracted_test 330
# Attempting: n/1297.jpg
# extracted_test 331
# Attempting: n/1298.jpg
# extracted_test 332
# Attempting: n/1299.jpg
# extracted_test 333
# Attempting: n/13.jpg
# extracted_test 334
# Attempting: n/130.jpg
# extracted_test 335
# Attempting: n/1300.jpg
# extracted_test 336
# Attempting: n/1301.jpg
# extracted_test 337
# Attempting: n/1302.jpg
# extracted_test 338
# Attempting: n/1303.jpg
# extracted_test 339
# Attempting: n/1304.jpg
# extracted_test 340
# Attempting: n/1305.jpg
# extracted_test 341
# Attempting: n/1306.jpg
# extracted_test 342
# Attempting: n/1307.jpg
# extracted_test 343
# Attempting: n/1308.jpg
# extracted_test 344
# Attempting: n/1309.jpg
# extracted_test 345
# Attempting: n/131.jpg
# extracted_test 346
# Attempting: n/1310.jpg
# extracted_test 347
# Attempting: n/1311.jpg
# extracted_test 348
# Attempting: n/1312.jpg
# extracted_test 349
# Attempting: n/1313.jpg
# extracted_test 350
# Attempting: n/1314.jpg
# extracted_test 351
# Attempting: n/1315.jpg
# extracted_test 352
# Attempting: n/1316.jpg
# extracted_test 353
# Attempting: n/1317.jpg
# extracted_test 354
# Attempting: n/1318.jpg
# extracted_test 355
# Attempting: n/1319.jpg
# extracted_test 356
# Attempting: n/132.jpg
# extracted_test 357
# Attempting: n/1320.jpg
# extracted_test 358
# Attempting: n/1321.jpg
# extracted_test 359
# Attempting: n/1322.jpg
# extracted_test 360
# Attempting: n/1323.jpg
# extracted_test 361
# Attempting: n/1324.jpg
# extracted_test 362
# Attempting: n/1325.jpg
# extracted_test 363
# Attempting: n/1326.jpg
# extracted_test 364
# Attempting: n/1327.jpg
# extracted_test 365
# Attempting: n/1328.jpg
# extracted_test 366
# Attempting: n/1329.jpg
# extracted_test 367
# Attempting: n/133.jpg
# extracted_test 368
# Attempting: n/1330.jpg
# extracted_test 369
# Attempting: n/1331.jpg
# extracted_test 370
# Attempting: n/1332.jpg
# extracted_test 371
# Attempting: n/1333.jpg
# extracted_test 372
# Attempting: n/1334.jpg
# extracted_test 373
# Attempting: n/1335.jpg
# extracted_test 374
# Attempting: n/1336.jpg
# extracted_test 375
# Attempting: n/1337.jpg
# extracted_test 376
# Attempting: n/1338.jpg
# extracted_test 377
# Attempting: n/1339.jpg
# extracted_test 378
# Attempting: n/134.jpg
# extracted_test 379
# Attempting: n/1340.jpg
# extracted_test 380
# Attempting: n/1341.jpg
# extracted_test 381
# Attempting: n/1342.jpg
# extracted_test 382
# Attempting: n/1343.jpg
# extracted_test 383
# Attempting: n/1344.jpg
# extracted_test 384
# Attempting: n/1345.jpg
# extracted_test 385
# Attempting: n/1346.jpg
# extracted_test 386
# Attempting: n/1347.jpg
# extracted_test 387
# Attempting: n/1348.jpg
# extracted_test 388
# Attempting: n/1349.jpg
# extracted_test 389
# Attempting: n/135.jpg
# extracted_test 390
# Attempting: n/1350.jpg
# extracted_test 391
# Attempting: n/1351.jpg
# extracted_test 392
# Attempting: n/1352.jpg
# extracted_test 393
# Attempting: n/1353.jpg
# extracted_test 394
# Attempting: n/1354.jpg
# extracted_test 395
# Attempting: n/1355.jpg
# extracted_test 396
# Attempting: n/1356.jpg
# extracted_test 397
# Attempting: n/1357.jpg
# extracted_test 398
# Attempting: n/1358.jpg
# extracted_test 399
# Attempting: n/1359.jpg
# extracted_test 400
# Attempting: n/136.jpg
# extracted_test 401
# Attempting: n/1360.jpg
# extracted_test 402
# Attempting: n/1361.jpg
# extracted_test 403
# Attempting: n/1362.jpg
# extracted_test 404
# Attempting: n/1363.jpg
# extracted_test 405
# Attempting: n/1364.jpg
# extracted_test 406
# Attempting: n/1365.jpg
# extracted_test 407
# Attempting: n/1366.jpg
# extracted_test 408
# Attempting: n/1367.jpg
# extracted_test 409
# Attempting: n/1368.jpg
# extracted_test 410
# Attempting: n/1369.jpg
# extracted_test 411
# Attempting: n/137.jpg
# extracted_test 412
# Attempting: n/1370.jpg
# extracted_test 413
# Attempting: n/1371.jpg
# extracted_test 414
# Attempting: n/1372.jpg
# extracted_test 415
# Attempting: n/1373.jpg
# extracted_test 416
# Attempting: n/1374.jpg
# failed to extract: n/1374.jpg
# Attempting: n/1375.jpg
# extracted_test 417
# Attempting: n/1376.jpg
# extracted_test 418
# Attempting: n/1377.jpg
# extracted_test 419
# Attempting: n/1378.jpg
# extracted_test 420
# Attempting: n/1379.jpg
# extracted_test 421
# Attempting: n/138.jpg
# extracted_test 422
# Attempting: n/1380.jpg
# extracted_test 423
# Attempting: n/1381.jpg
# extracted_test 424
# Attempting: n/1382.jpg
# extracted_test 425
# Attempting: n/1383.jpg
# extracted_test 426
# Attempting: n/1384.jpg
# extracted_test 427
# Attempting: n/1385.jpg
# extracted_test 428
# Attempting: n/1386.jpg
# extracted_test 429
# Attempting: n/1387.jpg
# extracted_test 430
# Attempting: n/1388.jpg
# extracted_test 431
# Attempting: n/1389.jpg
# extracted_test 432
# Attempting: n/139.jpg
# extracted_test 433
# Attempting: n/1390.jpg
# extracted_test 434
# Attempting: n/1391.jpg
# extracted_test 435
# Attempting: n/1392.jpg
# extracted_test 436
# Attempting: n/1393.jpg
# extracted_test 437
# Attempting: n/1394.jpg
# extracted_test 438
# Attempting: n/1395.jpg
# extracted_test 439
# Attempting: n/1396.jpg
# extracted_test 440
# Attempting: n/1397.jpg
# extracted_test 441
# Attempting: n/1398.jpg
# extracted_test 442
# Attempting: n/1399.jpg
# extracted_test 443
# Attempting: n/14.jpg
# extracted_test 444
# Attempting: n/140.jpg
# extracted_test 445
# Attempting: n/1400.jpg
# extracted_test 446
# Attempting: n/1401.jpg
# extracted_test 447
# Attempting: n/1402.jpg
# extracted_test 448
# Attempting: n/1403.jpg
# extracted_test 449
# Attempting: n/1404.jpg
# extracted_test 450
# Attempting: n/1405.jpg
# extracted_test 451
# Attempting: n/1406.jpg
# extracted_test 452
# Attempting: n/1407.jpg
# extracted_test 453
# Attempting: n/1408.jpg
# extracted_test 454
# Attempting: n/1409.jpg
# extracted_test 455
# Attempting: n/141.jpg
# extracted_test 456
# Attempting: n/1410.jpg
# extracted_test 457
# Attempting: n/1411.jpg
# extracted_test 458
# Attempting: n/1412.jpg
# extracted_test 459
# Attempting: n/1413.jpg
# extracted_test 460
# Attempting: n/1414.jpg
# extracted_test 461
# Attempting: n/1415.jpg
# extracted_test 462
# Attempting: n/1416.jpg
# extracted_test 463
# Attempting: n/1417.jpg
# extracted_test 464
# Attempting: n/1418.jpg
# extracted_test 465
# Attempting: n/1419.jpg
# extracted_test 466
# Attempting: n/142.jpg
# extracted_test 467
# Attempting: n/1420.jpg
# extracted_test 468
# Attempting: n/1421.jpg
# extracted_test 469
# Attempting: n/1422.jpg
# extracted_test 470
# Attempting: n/1423.jpg
# extracted_test 471
# Attempting: n/1424.jpg
# extracted_test 472
# Attempting: n/1425.jpg
# extracted_test 473
# Attempting: n/1426.jpg
# extracted_test 474
# Attempting: n/1427.jpg
# extracted_test 475
# Attempting: n/1428.jpg
# extracted_test 476
# Attempting: n/1429.jpg
# extracted_test 477
# Attempting: n/143.jpg
# extracted_test 478
# Attempting: n/1430.jpg
# extracted_test 479
# Attempting: n/1431.jpg
# extracted_test 480
# Attempting: n/1432.jpg
# extracted_test 481
# Attempting: n/1433.jpg
# extracted_test 482
# Attempting: n/1434.jpg
# extracted_test 483
# Attempting: n/1435.jpg
# extracted_test 484
# Attempting: n/1436.jpg
# extracted_test 485
# Attempting: n/1437.jpg
# extracted_test 486
# Attempting: n/1438.jpg
# extracted_test 487
# Attempting: n/1439.jpg
# extracted_test 488
# Attempting: n/144.jpg
# extracted_test 489
# Attempting: n/1440.jpg
# extracted_test 490
# Attempting: n/1441.jpg
# extracted_test 491
# Attempting: n/1442.jpg
# extracted_test 492
# Attempting: n/1443.jpg
# extracted_test 493
# Attempting: n/1444.jpg
# extracted_test 494
# Attempting: n/1445.jpg
# extracted_test 495
# Attempting: n/1446.jpg
# extracted_test 496
# Attempting: n/1447.jpg
# extracted_test 497
# Attempting: n/1448.jpg
# extracted_test 498
# Attempting: n/1449.jpg
# extracted_test 499
# Attempting: n/145.jpg
# extracted_test 500
# Attempting: n/1450.jpg
# extracted_test 501
# Attempting: n/1451.jpg
# extracted_test 502
# Attempting: n/1452.jpg
# extracted_test 503
# Attempting: n/1453.jpg
# extracted_test 504
# Attempting: n/1454.jpg
# extracted_test 505
# Attempting: n/1455.jpg
# extracted_test 506
# Attempting: n/1456.jpg
# extracted_test 507
# Attempting: n/1457.jpg
# extracted_test 508
# Attempting: n/1458.jpg
# extracted_test 509
# Attempting: n/1459.jpg
# extracted_test 510
# Attempting: n/146.jpg
# extracted_test 511
# Attempting: n/1460.jpg
# extracted_test 512
# Attempting: n/1461.jpg
# extracted_test 513
# Attempting: n/1462.jpg
# extracted_test 514
# Attempting: n/1463.jpg
# extracted_test 515
# Attempting: n/1464.jpg
# extracted_test 516
# Attempting: n/1465.jpg
# extracted_test 517
# Attempting: n/1466.jpg
# extracted_test 518
# Attempting: n/1467.jpg
# extracted_test 519
# Attempting: n/1468.jpg
# extracted_test 520
# Attempting: n/1469.jpg
# extracted_test 521
# Attempting: n/147.jpg
# extracted_test 522
# Attempting: n/1470.jpg
# extracted_test 523
# Attempting: n/1471.jpg
# extracted_test 524
# Attempting: n/1472.jpg
# extracted_test 525
# Attempting: n/1473.jpg
# extracted_test 526
# Attempting: n/1474.jpg
# extracted_test 527
# Attempting: n/1475.jpg
# extracted_test 528
# Attempting: n/1476.jpg
# extracted_test 529
# Attempting: n/1477.jpg
# extracted_test 530
# Attempting: n/1478.jpg
# extracted_test 531
# Attempting: n/1479.jpg
# extracted_test 532
# Attempting: n/148.jpg
# extracted_test 533
# Attempting: n/1480.jpg
# extracted_test 534
# Attempting: n/1481.jpg
# extracted_test 535
# Attempting: n/1482.jpg
# extracted_test 536
# Attempting: n/1483.jpg
# extracted_test 537
# Attempting: n/1484.jpg
# extracted_test 538
# Attempting: n/1485.jpg
# extracted_test 539
# Attempting: n/1486.jpg
# extracted_test 540
# Attempting: n/1487.jpg
# extracted_test 541
# Attempting: n/1488.jpg
# extracted_test 542
# Attempting: n/1489.jpg
# extracted_test 543
# Attempting: n/149.jpg
# extracted_test 544
# Attempting: n/1490.jpg
# extracted_test 545
# Attempting: n/1491.jpg
# failed to extract: n/1491.jpg
# Attempting: n/1492.jpg
# extracted_test 546
# Attempting: n/1493.jpg
# extracted_test 547
# Attempting: n/1494.jpg
# extracted_test 548
# Attempting: n/1495.jpg
# extracted_test 549
# Attempting: n/1496.jpg
# extracted_test 550
# Attempting: n/1497.jpg
# extracted_test 551
# Attempting: n/1498.jpg
# extracted_test 552
# Attempting: n/1499.jpg
# extracted_test 553
# Attempting: n/15.jpg
# extracted_test 554
# Attempting: n/150.jpg
# extracted_test 555
# Attempting: n/1500.jpg
# extracted_test 556
# Attempting: n/1501.jpg
# extracted_test 557
# Attempting: n/1502.jpg
# extracted_test 558
# Attempting: n/1503.jpg
# extracted_test 559
# Attempting: n/1504.jpg
# extracted_test 560
# Attempting: n/1505.jpg
# failed to extract: n/1505.jpg
# Attempting: n/1506.jpg
# extracted_test 561
# Attempting: n/1507.jpg
# extracted_test 562
# Attempting: n/1508.jpg
# extracted_test 563
# Attempting: n/1509.jpg
# extracted_test 564
# Attempting: n/151.jpg
# extracted_test 565
# Attempting: n/1510.jpg
# extracted_test 566
# Attempting: n/1511.jpg
# extracted_test 567
# Attempting: n/1512.jpg
# extracted_test 568
# Attempting: n/1513.jpg
# extracted_test 569
# Attempting: n/1514.jpg
# extracted_test 570
# Attempting: n/1515.jpg
# extracted_test 571
# Attempting: n/1516.jpg
# extracted_test 572
# Attempting: n/1517.jpg
# extracted_test 573
# Attempting: n/1518.jpg
# extracted_test 574
# Attempting: n/1519.jpg
# extracted_test 575
# Attempting: n/152.jpg
# extracted_test 576
# Attempting: n/1520.jpg
# extracted_test 577
# Attempting: n/1521.jpg
# extracted_test 578
# Attempting: n/1522.jpg
# extracted_test 579
# Attempting: n/1523.jpg
# extracted_test 580
# Attempting: n/1524.jpg
# extracted_test 581
# Attempting: n/1525.jpg
# extracted_test 582
# Attempting: n/1526.jpg
# extracted_test 583
# Attempting: n/1527.jpg
# extracted_test 584
# Attempting: n/1528.jpg
# extracted_test 585
# Attempting: n/1529.jpg
# extracted_test 586
# Attempting: n/153.jpg
# extracted_test 587
# Attempting: n/1530.jpg
# extracted_test 588
# Attempting: n/1531.jpg
# extracted_test 589
# Attempting: n/1532.jpg
# extracted_test 590
# Attempting: n/1533.jpg
# extracted_test 591
# Attempting: n/1534.jpg
# extracted_test 592
# Attempting: n/1535.jpg
# extracted_test 593
# Attempting: n/1536.jpg
# extracted_test 594
# Attempting: n/1537.jpg
# extracted_test 595
# Attempting: n/1538.jpg
# extracted_test 596
# Attempting: n/1539.jpg
# extracted_test 597
# Attempting: n/154.jpg
# extracted_test 598
# Attempting: n/1540.jpg
# extracted_test 599
# Attempting: n/1541.jpg
# extracted_test 600
# Attempting: n/1542.jpg
# extracted_test 601
# Attempting: n/1543.jpg
# extracted_test 602
# Attempting: n/1544.jpg
# extracted_test 603
# Attempting: n/1545.jpg
# extracted_test 604
# Attempting: n/1546.jpg
# extracted_test 605
# Attempting: n/1547.jpg
# extracted_test 606
# Attempting: n/1548.jpg
# extracted_test 607
# Attempting: n/1549.jpg
# extracted_test 608
# Attempting: n/155.jpg
# extracted_test 609
# Attempting: n/1550.jpg
# extracted_test 610
# Attempting: n/1551.jpg
# extracted_test 611
# Attempting: n/1552.jpg
# extracted_test 612
# Attempting: n/1553.jpg
# extracted_test 613
# Attempting: n/1554.jpg
# extracted_test 614
# Attempting: n/1555.jpg
# extracted_test 615
# Attempting: n/1556.jpg
# extracted_test 616
# Attempting: n/1557.jpg
# extracted_test 617
# Attempting: n/1558.jpg
# extracted_test 618
# Attempting: n/1559.jpg
# extracted_test 619
# Attempting: n/156.jpg
# extracted_test 620
# Attempting: n/1560.jpg
# extracted_test 621
# Attempting: n/1561.jpg
# extracted_test 622
# Attempting: n/1562.jpg
# extracted_test 623
# Attempting: n/1563.jpg
# extracted_test 624
# Attempting: n/1564.jpg
# extracted_test 625
# Attempting: n/1565.jpg
# extracted_test 626
# Attempting: n/1566.jpg
# extracted_test 627
# Attempting: n/1567.jpg
# failed to extract: n/1567.jpg
# Attempting: n/1568.jpg
# extracted_test 628
# Attempting: n/1569.jpg
# extracted_test 629
# Attempting: n/157.jpg
# extracted_test 630
# Attempting: n/1570.jpg
# extracted_test 631
# Attempting: n/1571.jpg
# extracted_test 632
# Attempting: n/1572.jpg
# extracted_test 633
# Attempting: n/1573.jpg
# extracted_test 634
# Attempting: n/1574.jpg
# extracted_test 635
# Attempting: n/1575.jpg
# extracted_test 636
# Attempting: n/1576.jpg
# extracted_test 637
# Attempting: n/1577.jpg
# extracted_test 638
# Attempting: n/1578.jpg
# extracted_test 639
# Attempting: n/1579.jpg
# extracted_test 640
# Attempting: n/158.jpg
# extracted_test 641
# Attempting: n/1580.jpg
# extracted_test 642
# Attempting: n/1581.jpg
# extracted_test 643
# Attempting: n/1582.jpg
# extracted_test 644
# Attempting: n/1583.jpg
# extracted_test 645
# Attempting: n/1584.jpg
# extracted_test 646
# Attempting: n/1585.jpg
# extracted_test 647
# Attempting: n/1586.jpg
# extracted_test 648
# Attempting: n/1587.jpg
# extracted_test 649
# Attempting: n/1588.jpg
# extracted_test 650
# Attempting: n/1589.jpg
# extracted_test 651
# Attempting: n/159.jpg
# extracted_test 652
# Attempting: n/1590.jpg
# extracted_test 653
# Attempting: n/1591.jpg
# extracted_test 654
# Attempting: n/1592.jpg
# extracted_test 655
# Attempting: n/1593.jpg
# extracted_test 656
# Attempting: n/1594.jpg
# extracted_test 657
# Attempting: n/1595.jpg
# extracted_test 658
# Attempting: n/1596.jpg
# extracted_test 659
# Attempting: n/1597.jpg
# extracted_test 660
# Attempting: n/1598.jpg
# extracted_test 661
# Attempting: n/1599.jpg
# extracted_test 662
# Attempting: n/16.jpg
# extracted_test 663
# Attempting: n/160.jpg
# extracted_test 664
# Attempting: n/1600.jpg
# extracted_test 665
# Attempting: n/1601.jpg
# extracted_test 666
# Attempting: n/1602.jpg
# extracted_test 667
# Attempting: n/1603.jpg
# extracted_test 668
# Attempting: n/1604.jpg
# extracted_test 669
# Attempting: n/1605.jpg
# extracted_test 670
# Attempting: n/1606.jpg
# extracted_test 671
# Attempting: n/1607.jpg
# extracted_test 672
# Attempting: n/1608.jpg
# extracted_test 673
# Attempting: n/1609.jpg
# extracted_test 674
# Attempting: n/161.jpg
# extracted_test 675
# Attempting: n/1610.jpg
# extracted_test 676
# Attempting: n/1611.jpg
# extracted_test 677
# Attempting: n/1612.jpg
# extracted_test 678
# Attempting: n/1613.jpg
# extracted_test 679
# Attempting: n/1614.jpg
# extracted_test 680
# Attempting: n/1615.jpg
# extracted_test 681
# Attempting: n/1616.jpg
# extracted_test 682
# Attempting: n/1617.jpg
# extracted_test 683
# Attempting: n/1618.jpg
# extracted_test 684
# Attempting: n/1619.jpg
# extracted_test 685
# Attempting: n/162.jpg
# extracted_test 686
# Attempting: n/1620.jpg
# extracted_test 687
# Attempting: n/1621.jpg
# extracted_test 688
# Attempting: n/1622.jpg
# extracted_test 689
# Attempting: n/1623.jpg
# extracted_test 690
# Attempting: n/1624.jpg
# extracted_test 691
# Attempting: n/1625.jpg
# extracted_test 692
# Attempting: n/1626.jpg
# extracted_test 693
# Attempting: n/1627.jpg
# extracted_test 694
# Attempting: n/1628.jpg
# extracted_test 695
# Attempting: n/1629.jpg
# extracted_test 696
# Attempting: n/163.jpg
# extracted_test 697
# Attempting: n/1630.jpg
# extracted_test 698
# Attempting: n/1631.jpg
# extracted_test 699
# Attempting: n/1632.jpg
# extracted_test 700
# Attempting: n/1633.jpg
# extracted_test 701
# Attempting: n/1634.jpg
# extracted_test 702
# Attempting: n/1635.jpg
# extracted_test 703
# Attempting: n/1636.jpg
# extracted_test 704
# Attempting: n/1637.jpg
# extracted_test 705
# Attempting: n/1638.jpg
# extracted_test 706
# Attempting: n/1639.jpg
# extracted_test 707
# Attempting: n/164.jpg
# extracted_test 708
# Attempting: n/1640.jpg
# extracted_test 709
# Attempting: n/1641.jpg
# extracted_test 710
# Attempting: n/1642.jpg
# extracted_test 711
# Attempting: n/1643.jpg
# extracted_test 712
# Attempting: n/1644.jpg
# extracted_test 713
# Attempting: n/1645.jpg
# extracted_test 714
# Attempting: n/1646.jpg
# extracted_test 715
# Attempting: n/1647.jpg
# extracted_test 716
# Attempting: n/1648.jpg
# extracted_test 717
# Attempting: n/1649.jpg
# extracted_test 718
# Attempting: n/165.jpg
# extracted_test 719
# Attempting: n/1650.jpg
# extracted_test 720
# Attempting: n/1651.jpg
# extracted_test 721
# Attempting: n/1652.jpg
# extracted_test 722
# Attempting: n/1653.jpg
# extracted_test 723
# Attempting: n/1654.jpg
# extracted_test 724
# Attempting: n/1655.jpg
# extracted_test 725
# Attempting: n/1656.jpg
# extracted_test 726
# Attempting: n/1657.jpg
# extracted_test 727
# Attempting: n/1658.jpg
# extracted_test 728
# Attempting: n/1659.jpg
# extracted_test 729
# Attempting: n/166.jpg
# extracted_test 730
# Attempting: n/1660.jpg
# extracted_test 731
# Attempting: n/1661.jpg
# failed to extract: n/1661.jpg
# Attempting: n/1662.jpg
# extracted_test 732
# Attempting: n/1663.jpg
# extracted_test 733
# Attempting: n/1664.jpg
# extracted_test 734
# Attempting: n/1665.jpg
# extracted_test 735
# Attempting: n/1666.jpg
# extracted_test 736
# Attempting: n/1667.jpg
# extracted_test 737
# Attempting: n/1668.jpg
# extracted_test 738
# Attempting: n/1669.jpg
# extracted_test 739
# Attempting: n/167.jpg
# extracted_test 740
# Attempting: n/1670.jpg
# extracted_test 741
# Attempting: n/1671.jpg
# extracted_test 742
# Attempting: n/1672.jpg
# extracted_test 743
# Attempting: n/1673.jpg
# extracted_test 744
# Attempting: n/1674.jpg
# extracted_test 745
# Attempting: n/1675.jpg
# extracted_test 746
# Attempting: n/1676.jpg
# extracted_test 747
# Attempting: n/1677.jpg
# extracted_test 748
# Attempting: n/1678.jpg
# extracted_test 749
# Attempting: n/1679.jpg
# extracted_test 750
# Attempting: n/168.jpg
# extracted_test 751
# Attempting: n/1680.jpg
# extracted_test 752
# Attempting: n/1681.jpg
# extracted_test 753
# Attempting: n/1682.jpg
# extracted_test 754
# Attempting: n/1683.jpg
# extracted_test 755
# Attempting: n/1684.jpg
# extracted_test 756
# Attempting: n/1685.jpg
# extracted_test 757
# Attempting: n/1686.jpg
# extracted_test 758
# Attempting: n/1687.jpg
# extracted_test 759
# Attempting: n/1688.jpg
# extracted_test 760
# Attempting: n/1689.jpg
# extracted_test 761
# Attempting: n/169.jpg
# extracted_test 762
# Attempting: n/1690.jpg
# extracted_test 763
# Attempting: n/1691.jpg
# extracted_test 764
# Attempting: n/1692.jpg
# extracted_test 765
# Attempting: n/1693.jpg
# extracted_test 766
# Attempting: n/1694.jpg
# extracted_test 767
# Attempting: n/1695.jpg
# extracted_test 768
# Attempting: n/1696.jpg
# extracted_test 769
# Attempting: n/1697.jpg
# extracted_test 770
# Attempting: n/1698.jpg
# extracted_test 771
# Attempting: n/1699.jpg
# extracted_test 772
# Attempting: n/17.jpg
# extracted_test 773
# Attempting: n/170.jpg
# extracted_test 774
# Attempting: n/1700.jpg
# extracted_test 775
# Attempting: n/1701.jpg
# extracted_test 776
# Attempting: n/1702.jpg
# extracted_test 777
# Attempting: n/1703.jpg
# extracted_test 778
# Attempting: n/1704.jpg
# extracted_test 779
# Attempting: n/1705.jpg
# extracted_test 780
# Attempting: n/1706.jpg
# extracted_test 781
# Attempting: n/1707.jpg
# extracted_test 782
# Attempting: n/1708.jpg
# extracted_test 783
# Attempting: n/1709.jpg
# extracted_test 784
# Attempting: n/171.jpg
# extracted_test 785
# Attempting: n/1710.jpg
# extracted_test 786
# Attempting: n/1711.jpg
# extracted_test 787
# Attempting: n/1712.jpg
# extracted_test 788
# Attempting: n/1713.jpg
# extracted_test 789
# Attempting: n/1714.jpg
# extracted_test 790
# Attempting: n/1715.jpg
# extracted_test 791
# Attempting: n/1716.jpg
# extracted_test 792
# Attempting: n/1717.jpg
# extracted_test 793
# Attempting: n/1718.jpg
# extracted_test 794
# Attempting: n/1719.jpg
# extracted_test 795
# Attempting: n/172.jpg
# extracted_test 796
# Attempting: n/1720.jpg
# extracted_test 797
# Attempting: n/1721.jpg
# extracted_test 798
# Attempting: n/1722.jpg
# failed to extract: n/1722.jpg
# Attempting: n/1723.jpg
# extracted_test 799
# Attempting: n/1724.jpg
# extracted_test 800
# Attempting: n/1725.jpg
# extracted_test 801
# Attempting: n/1726.jpg
# extracted_test 802
# Attempting: n/1727.jpg
# extracted_test 803
# Attempting: n/1728.jpg
# extracted_test 804
# Attempting: n/1729.jpg
# extracted_test 805
# Attempting: n/173.jpg
# extracted_test 806
# Attempting: n/1730.jpg
# extracted_test 807
# Attempting: n/1731.jpg
# extracted_test 808
# Attempting: n/1732.jpg
# extracted_test 809
# Attempting: n/1733.jpg
# extracted_test 810
# Attempting: n/1734.jpg
# extracted_test 811
# Attempting: n/1735.jpg
# extracted_test 812
# Attempting: n/1736.jpg
# extracted_test 813
# Attempting: n/1737.jpg
# extracted_test 814
# Attempting: n/1738.jpg
# extracted_test 815
# Attempting: n/1739.jpg
# extracted_test 816
# Attempting: n/174.jpg
# extracted_test 817
# Attempting: n/1740.jpg
# extracted_test 818
# Attempting: n/1741.jpg
# extracted_test 819
# Attempting: n/1742.jpg
# extracted_test 820
# Attempting: n/1743.jpg
# extracted_test 821
# Attempting: n/1744.jpg
# extracted_test 822
# Attempting: n/1745.jpg
# extracted_test 823
# Attempting: n/1746.jpg
# extracted_test 824
# Attempting: n/1747.jpg
# extracted_test 825
# Attempting: n/1748.jpg
# extracted_test 826
# Attempting: n/1749.jpg
# extracted_test 827
# Attempting: n/175.jpg
# extracted_test 828
# Attempting: n/1750.jpg
# extracted_test 829
# Attempting: n/1751.jpg
# extracted_test 830
# Attempting: n/1752.jpg
# extracted_test 831
# Attempting: n/1753.jpg
# extracted_test 832
# Attempting: n/1754.jpg
# extracted_test 833
# Attempting: n/1755.jpg
# extracted_test 834
# Attempting: n/1756.jpg
# extracted_test 835
# Attempting: n/1757.jpg
# failed to extract: n/1757.jpg
# Attempting: n/1758.jpg
# extracted_test 836
# Attempting: n/1759.jpg
# extracted_test 837
# Attempting: n/176.jpg
# extracted_test 838
# Attempting: n/1760.jpg
# extracted_test 839
# Attempting: n/1761.jpg
# extracted_test 840
# Attempting: n/1762.jpg
# extracted_test 841
# Attempting: n/1763.jpg
# extracted_test 842
# Attempting: n/1764.jpg
# extracted_test 843
# Attempting: n/1765.jpg
# extracted_test 844
# Attempting: n/1766.jpg
# extracted_test 845
# Attempting: n/1767.jpg
# extracted_test 846
# Attempting: n/1768.jpg
# extracted_test 847
# Attempting: n/1769.jpg
# extracted_test 848
# Attempting: n/177.jpg
# extracted_test 849
# Attempting: n/1770.jpg
# extracted_test 850
# Attempting: n/1771.jpg
# extracted_test 851
# Attempting: n/1772.jpg
# extracted_test 852
# Attempting: n/1773.jpg
# extracted_test 853
# Attempting: n/1774.jpg
# extracted_test 854
# Attempting: n/1775.jpg
# extracted_test 855
# Attempting: n/1776.jpg
# extracted_test 856
# Attempting: n/1777.jpg
# failed to extract: n/1777.jpg
# Attempting: n/1778.jpg
# extracted_test 857
# Attempting: n/1779.jpg
# extracted_test 858
# Attempting: n/178.jpg
# extracted_test 859
# Attempting: n/1780.jpg
# extracted_test 860
# Attempting: n/1781.jpg
# extracted_test 861
# Attempting: n/1782.jpg
# extracted_test 862
# Attempting: n/1783.jpg
# extracted_test 863
# Attempting: n/1784.jpg
# extracted_test 864
# Attempting: n/1785.jpg
# extracted_test 865
# Attempting: n/1786.jpg
# extracted_test 866
# Attempting: n/1787.jpg
# extracted_test 867
# Attempting: n/1788.jpg
# extracted_test 868
# Attempting: n/1789.jpg
# extracted_test 869
# Attempting: n/179.jpg
# extracted_test 870
# Attempting: n/1790.jpg
# extracted_test 871
# Attempting: n/1791.jpg
# extracted_test 872
# Attempting: n/1792.jpg
# extracted_test 873
# Attempting: n/1793.jpg
# extracted_test 874
# Attempting: n/1794.jpg
# extracted_test 875
# Attempting: n/1795.jpg
# extracted_test 876
# Attempting: n/1796.jpg
# extracted_test 877
# Attempting: n/1797.jpg
# extracted_test 878
# Attempting: n/1798.jpg
# extracted_test 879
# Attempting: n/1799.jpg
# extracted_test 880
# Attempting: n/18.jpg
# extracted_test 881
# Attempting: n/180.jpg
# extracted_test 882
# Attempting: n/1800.jpg
# failed to extract: n/1800.jpg
# Attempting: n/1801.jpg
# extracted_test 883
# Attempting: n/1802.jpg
# extracted_test 884
# Attempting: n/1803.jpg
# extracted_test 885
# Attempting: n/1804.jpg
# extracted_test 886
# Attempting: n/1805.jpg
# extracted_test 887
# Attempting: n/1806.jpg
# extracted_test 888
# Attempting: n/1807.jpg
# extracted_test 889
# Attempting: n/1808.jpg
# extracted_test 890
# Attempting: n/1809.jpg
# extracted_test 891
# Attempting: n/181.jpg
# extracted_test 892
# Attempting: n/1810.jpg
# extracted_test 893
# Attempting: n/1811.jpg
# extracted_test 894
# Attempting: n/1812.jpg
# extracted_test 895
# Attempting: n/1813.jpg
# extracted_test 896
# Attempting: n/1814.jpg
# extracted_test 897
# Attempting: n/1815.jpg
# extracted_test 898
# Attempting: n/1816.jpg
# extracted_test 899
# Attempting: n/1817.jpg
# extracted_test 900
# Attempting: n/1818.jpg
# extracted_test 901
# Attempting: n/1819.jpg
# extracted_test 902
# Attempting: n/182.jpg
# extracted_test 903
# Attempting: n/1820.jpg
# extracted_test 904
# Attempting: n/1821.jpg
# extracted_test 905
# Attempting: n/1822.jpg
# extracted_test 906
# Attempting: n/1823.jpg
# extracted_test 907
# Attempting: n/1824.jpg
# extracted_test 908
# Attempting: n/1825.jpg
# extracted_test 909
# Attempting: n/1826.jpg
# extracted_test 910
# Attempting: n/1827.jpg
# extracted_test 911
# Attempting: n/1828.jpg
# extracted_test 912
# Attempting: n/1829.jpg
# extracted_test 913
# Attempting: n/183.jpg
# extracted_test 914
# Attempting: n/1830.jpg
# extracted_test 915
# Attempting: n/1831.jpg
# extracted_test 916
# Attempting: n/1832.jpg
# extracted_test 917
# Attempting: n/1833.jpg
# extracted_test 918
# Attempting: n/1834.jpg
# extracted_test 919
# Attempting: n/1835.jpg
# extracted_test 920
# Attempting: n/1836.jpg
# extracted_test 921
# Attempting: n/1837.jpg
# extracted_test 922
# Attempting: n/1838.jpg
# extracted_test 923
# Attempting: n/1839.jpg
# extracted_test 924
# Attempting: n/184.jpg
# extracted_test 925
# Attempting: n/1840.jpg
# extracted_test 926
# Attempting: n/1841.jpg
# extracted_test 927
# Attempting: n/1842.jpg
# extracted_test 928
# Attempting: n/1843.jpg
# extracted_test 929
# Attempting: n/1844.jpg
# extracted_test 930
# Attempting: n/1845.jpg
# extracted_test 931
# Attempting: n/1846.jpg
# failed to extract: n/1846.jpg
# Attempting: n/1847.jpg
# extracted_test 932
# Attempting: n/1848.jpg
# extracted_test 933
# Attempting: n/1849.jpg
# extracted_test 934
# Attempting: n/185.jpg
# extracted_test 935
# Attempting: n/1850.jpg
# extracted_test 936
# Attempting: n/1851.jpg
# extracted_test 937
# Attempting: n/1852.jpg
# extracted_test 938
# Attempting: n/1853.jpg
# extracted_test 939
# Attempting: n/1854.jpg
# extracted_test 940
# Attempting: n/1855.jpg
# extracted_test 941
# Attempting: n/1856.jpg
# extracted_test 942
# Attempting: n/1857.jpg
# extracted_test 943
# Attempting: n/1858.jpg
# extracted_test 944
# Attempting: n/1859.jpg
# extracted_test 945
# Attempting: n/186.jpg
# extracted_test 946
# Attempting: n/1860.jpg
# extracted_test 947
# Attempting: n/1861.jpg
# extracted_test 948
# Attempting: n/1862.jpg
# extracted_test 949
# Attempting: n/1863.jpg
# extracted_test 950
# Attempting: n/1864.jpg
# extracted_test 951
# Attempting: n/1865.jpg
# extracted_test 952
# Attempting: n/1866.jpg
# extracted_test 953
# Attempting: n/1867.jpg
# extracted_test 954
# Attempting: n/1868.jpg
# extracted_test 955
# Attempting: n/1869.jpg
# extracted_test 956
# Attempting: n/187.jpg
# extracted_test 957
# Attempting: n/1870.jpg
# extracted_test 958
# Attempting: n/1871.jpg
# extracted_test 959
# Attempting: n/1872.jpg
# extracted_test 960
# Attempting: n/1873.jpg
# extracted_test 961
# Attempting: n/1874.jpg
# extracted_test 962
# Attempting: n/1875.jpg
# extracted_test 963
# Attempting: n/1876.jpg
# extracted_test 964
# Attempting: n/1877.jpg
# extracted_test 965
# Attempting: n/1878.jpg
# extracted_test 966
# Attempting: n/1879.jpg
# extracted_test 967
# Attempting: n/188.jpg
# extracted_test 968
# Attempting: n/1880.jpg
# extracted_test 969
# Attempting: n/1881.jpg
# extracted_test 970
# Attempting: n/1882.jpg
# extracted_test 971
# Attempting: n/1883.jpg
# extracted_test 972
# Attempting: n/1884.jpg
# extracted_test 973
# Attempting: n/1885.jpg
# extracted_test 974
# Attempting: n/1886.jpg
# extracted_test 975
# Attempting: n/1887.jpg
# extracted_test 976
# Attempting: n/1888.jpg
# extracted_test 977
# Attempting: n/1889.jpg
# extracted_test 978
# Attempting: n/189.jpg
# extracted_test 979
# Attempting: n/1890.jpg
# extracted_test 980
# Attempting: n/1891.jpg
# extracted_test 981
# Attempting: n/1892.jpg
# extracted_test 982
# Attempting: n/1893.jpg
# extracted_test 983
# Attempting: n/1894.jpg
# extracted_test 984
# Attempting: n/1895.jpg
# extracted_test 985
# Attempting: n/1896.jpg
# extracted_test 986
# Attempting: n/1897.jpg
# extracted_test 987
# Attempting: n/1898.jpg
# extracted_test 988
# Attempting: n/1899.jpg
# extracted_test 989
# Attempting: n/19.jpg
# extracted_test 990
# Attempting: n/190.jpg
# extracted_test 991
# Attempting: n/1900.jpg
# extracted_test 992
# Attempting: n/1901.jpg
# extracted_test 993
# Attempting: n/1902.jpg
# extracted_test 994
# Attempting: n/1903.jpg
# extracted_test 995
# Attempting: n/1904.jpg
# extracted_test 996
# Attempting: n/1905.jpg
# extracted_test 997
# Attempting: n/1906.jpg
# extracted_test 998
# Attempting: n/1907.jpg
# extracted_test 999
# Attempting: n/1908.jpg
# extracted_test 1000
# Attempting: n/1909.jpg
# extracted_test 1001
# Attempting: n/191.jpg
# extracted_test 1002
# Attempting: n/1910.jpg
# extracted_test 1003
# Attempting: n/1911.jpg
# extracted_test 1004
# Attempting: n/1912.jpg
# extracted_test 1005
# Attempting: n/1913.jpg
# extracted_test 1006
# Attempting: n/1914.jpg
# extracted_test 1007
# Attempting: n/1915.jpg
# extracted_test 1008
# Attempting: n/1916.jpg
# extracted_test 1009
# Attempting: n/1917.jpg
# extracted_test 1010
# Attempting: n/1918.jpg
# extracted_test 1011
# Attempting: n/1919.jpg
# extracted_test 1012
# Attempting: n/192.jpg
# extracted_test 1013
# Attempting: n/1920.jpg
# extracted_test 1014
# Attempting: n/1921.jpg
# extracted_test 1015
# Attempting: n/1922.jpg
# extracted_test 1016
# Attempting: n/1923.jpg
# extracted_test 1017
# Attempting: n/1924.jpg
# extracted_test 1018
# Attempting: n/1925.jpg
# extracted_test 1019
# Attempting: n/1926.jpg
# extracted_test 1020
# Attempting: n/1927.jpg
# extracted_test 1021
# Attempting: n/1928.jpg
# extracted_test 1022
# Attempting: n/1929.jpg
# extracted_test 1023
# Attempting: n/193.jpg
# extracted_test 1024
# Attempting: n/1930.jpg
# extracted_test 1025
# Attempting: n/1931.jpg
# extracted_test 1026
# Attempting: n/1932.jpg
# extracted_test 1027
# Attempting: n/1933.jpg
# extracted_test 1028
# Attempting: n/1934.jpg
# extracted_test 1029
# Attempting: n/1935.jpg
# extracted_test 1030
# Attempting: n/1936.jpg
# extracted_test 1031
# Attempting: n/1937.jpg
# extracted_test 1032
# Attempting: n/1938.jpg
# extracted_test 1033
# Attempting: n/1939.jpg
# extracted_test 1034
# Attempting: n/194.jpg
# extracted_test 1035
# Attempting: n/1940.jpg
# extracted_test 1036
# Attempting: n/1941.jpg
# extracted_test 1037
# Attempting: n/1942.jpg
# extracted_test 1038
# Attempting: n/1943.jpg
# extracted_test 1039
# Attempting: n/1944.jpg
# extracted_test 1040
# Attempting: n/1945.jpg
# extracted_test 1041
# Attempting: n/1946.jpg
# extracted_test 1042
# Attempting: n/1947.jpg
# extracted_test 1043
# Attempting: n/1948.jpg
# extracted_test 1044
# Attempting: n/1949.jpg
# extracted_test 1045
# Attempting: n/195.jpg
# failed to extract: n/195.jpg
# Attempting: n/1950.jpg
# extracted_test 1046
# Attempting: n/1951.jpg
# extracted_test 1047
# Attempting: n/1952.jpg
# extracted_test 1048
# Attempting: n/1953.jpg
# extracted_test 1049
# Attempting: n/1954.jpg
# extracted_test 1050
# Attempting: n/1955.jpg
# extracted_test 1051
# Attempting: n/1956.jpg
# extracted_test 1052
# Attempting: n/1957.jpg
# extracted_test 1053
# Attempting: n/1958.jpg
# extracted_test 1054
# Attempting: n/1959.jpg
# extracted_test 1055
# Attempting: n/196.jpg
# extracted_test 1056
# Attempting: n/1960.jpg
# extracted_test 1057
# Attempting: n/1961.jpg
# extracted_test 1058
# Attempting: n/1962.jpg
# extracted_test 1059
# Attempting: n/1963.jpg
# extracted_test 1060
# Attempting: n/1964.jpg
# extracted_test 1061
# Attempting: n/1965.jpg
# extracted_test 1062
# Attempting: n/1966.jpg
# extracted_test 1063
# Attempting: n/1967.jpg
# extracted_test 1064
# Attempting: n/1968.jpg
# extracted_test 1065
# Attempting: n/1969.jpg
# extracted_test 1066
# Attempting: n/197.jpg
# extracted_test 1067
# Attempting: n/1970.jpg
# extracted_test 1068
# Attempting: n/1971.jpg
# extracted_test 1069
# Attempting: n/1972.jpg
# extracted_test 1070
# Attempting: n/1973.jpg
# extracted_test 1071
# Attempting: n/1974.jpg
# extracted_test 1072
# Attempting: n/1975.jpg
# extracted_test 1073
# Attempting: n/1976.jpg
# extracted_test 1074
# Attempting: n/1977.jpg
# extracted_test 1075
# Attempting: n/1978.jpg
# extracted_test 1076
# Attempting: n/1979.jpg
# extracted_test 1077
# Attempting: n/198.jpg
# extracted_test 1078
# Attempting: n/1980.jpg
# extracted_test 1079
# Attempting: n/1981.jpg
# extracted_test 1080
# Attempting: n/1982.jpg
# extracted_test 1081
# Attempting: n/1983.jpg
# extracted_test 1082
# Attempting: n/1984.jpg
# extracted_test 1083
# Attempting: n/1985.jpg
# extracted_test 1084
# Attempting: n/1986.jpg
# extracted_test 1085
# Attempting: n/1987.jpg
# extracted_test 1086
# Attempting: n/1988.jpg
# extracted_test 1087
# Attempting: n/1989.jpg
# extracted_test 1088
# Attempting: n/199.jpg
# extracted_test 1089
# Attempting: n/1990.jpg
# extracted_test 1090
# Attempting: n/1991.jpg
# extracted_test 1091
# Attempting: n/1992.jpg
# extracted_test 1092
# Attempting: n/1993.jpg
# extracted_test 1093
# Attempting: n/1994.jpg
# extracted_test 1094
# Attempting: n/1995.jpg
# extracted_test 1095
# Attempting: n/1996.jpg
# extracted_test 1096
# Attempting: n/1997.jpg
# extracted_test 1097
# Attempting: n/1998.jpg
# extracted_test 1098
# Attempting: n/1999.jpg
# extracted_test 1099
# Attempting: n/2.jpg
# extracted_test 1100
# Attempting: n/20.jpg
# extracted_test 1101
# Attempting: n/200.jpg
# extracted_test 1102
# Attempting: n/2000.jpg
# extracted_test 1103
# Attempting: n/2001.jpg
# extracted_test 1104
# Attempting: n/2002.jpg
# extracted_test 1105
# Attempting: n/2003.jpg
# extracted_test 1106
# Attempting: n/2004.jpg
# extracted_test 1107
# Attempting: n/2005.jpg
# extracted_test 1108
# Attempting: n/2006.jpg
# extracted_test 1109
# Attempting: n/2007.jpg
# extracted_test 1110
# Attempting: n/2008.jpg
# extracted_test 1111
# Attempting: n/2009.jpg
# extracted_test 1112
# Attempting: n/201.jpg
# extracted_test 1113
# Attempting: n/2010.jpg
# extracted_test 1114
# Attempting: n/2011.jpg
# extracted_test 1115
# Attempting: n/2012.jpg
# extracted_test 1116
# Attempting: n/2013.jpg
# extracted_test 1117
# Attempting: n/2014.jpg
# extracted_test 1118
# Attempting: n/2015.jpg
# extracted_test 1119
# Attempting: n/2016.jpg
# extracted_test 1120
# Attempting: n/2017.jpg
# extracted_test 1121
# Attempting: n/2018.jpg
# extracted_test 1122
# Attempting: n/2019.jpg
# extracted_test 1123
# Attempting: n/202.jpg
# extracted_test 1124
# Attempting: n/2020.jpg
# extracted_test 1125
# Attempting: n/2021.jpg
# extracted_test 1126
# Attempting: n/2022.jpg
# extracted_test 1127
# Attempting: n/2023.jpg
# extracted_test 1128
# Attempting: n/2024.jpg
# extracted_test 1129
# Attempting: n/2025.jpg
# extracted_test 1130
# ...
# Attempting: n/7138.jpg
# extracted_test 6741
# Attempting: n/7139.jpg
# extracted_test 6742
# Attempting: n/714.jpg
# extracted_test 6743
# Attempting: n/7140.jpg
# extracted_test 6744
# Attempting: n/7141.jpg
# extracted_test 6745
# Attempting: n/7142.jpg
# extracted_test 6746
# Attempting: n/7143.jpg
# extracted_test 6747
# Attempting: n/7144.jpg
# extracted_test 6748
# Attempting: n/7145.jpg
# extracted_test 6749
# Attempting: n/7146.jpg
# extracted_test 6750
# Attempting: n/7147.jpg
# extracted_test 6751
# Attempting: n/7148.jpg
# extracted_test 6752
# Attempting: n/7149.jpg
# extracted_test 6753
# Attempting: n/715.jpg
# extracted_test 6754
# Attempting: n/7150.jpg
# extracted_test 6755
# Attempting: n/7151.jpg
# extracted_test 6756
# Attempting: n/7152.jpg
# extracted_test 6757
# Attempting: n/7153.jpg
# extracted_test 6758
# Attempting: n/7154.jpg
# extracted_test 6759
# Attempting: n/7155.jpg
# extracted_test 6760
# Attempting: n/7156.jpg
# extracted_test 6761
# Attempting: n/7157.jpg
# extracted_test 6762
# Attempting: n/7158.jpg
# extracted_test 6763
# Attempting: n/7159.jpg
# extracted_test 6764
# Attempting: n/716.jpg
# extracted_test 6765
# Attempting: n/7160.jpg
# extracted_test 6766
# Attempting: n/7161.jpg
# extracted_test 6767
# Attempting: n/7162.jpg
# extracted_test 6768
# Attempting: n/7163.jpg
# extracted_test 6769
# Attempting: n/7164.jpg
# extracted_test 6770
# Attempting: n/7165.jpg
# extracted_test 6771
# Attempting: n/7166.jpg
# extracted_test 6772
# Attempting: n/7167.jpg
# extracted_test 6773
# Attempting: n/7168.jpg
# extracted_test 6774
# Attempting: n/7169.jpg
# extracted_test 6775
# Attempting: n/717.jpg
# extracted_test 6776
# Attempting: n/7170.jpg
# extracted_test 6777
# Attempting: n/7171.jpg
# extracted_test 6778
# Attempting: n/7172.jpg
# extracted_test 6779
# Attempting: n/7173.jpg
# extracted_test 6780
# Attempting: n/7174.jpg
# extracted_test 6781
# Attempting: n/7175.jpg
# extracted_test 6782
# Attempting: n/7176.jpg
# extracted_test 6783
# Attempting: n/7177.jpg
# extracted_test 6784
# Attempting: n/7178.jpg
# extracted_test 6785
# Attempting: n/7179.jpg
# extracted_test 6786
# Attempting: n/718.jpg
# extracted_test 6787
# Attempting: n/7180.jpg
# extracted_test 6788
# Attempting: n/7181.jpg
# extracted_test 6789
# Attempting: n/7182.jpg
# extracted_test 6790
# Attempting: n/7183.jpg
# extracted_test 6791
# Attempting: n/7184.jpg
# extracted_test 6792
# Attempting: n/7185.jpg
# extracted_test 6793
# Attempting: n/7186.jpg
# extracted_test 6794
# Attempting: n/7187.jpg
# extracted_test 6795
# Attempting: n/7188.jpg
# extracted_test 6796
# Attempting: n/7189.jpg
# extracted_test 6797
# Attempting: n/719.jpg
# extracted_test 6798
# Attempting: n/7190.jpg
# extracted_test 6799
# Attempting: n/7191.jpg
# extracted_test 6800
# Attempting: n/7192.jpg
# extracted_test 6801
# Attempting: n/7193.jpg
# extracted_test 6802
# Attempting: n/7194.jpg
# extracted_test 6803
# Attempting: n/7195.jpg
# extracted_test 6804
# Attempting: n/7196.jpg
# extracted_test 6805
# Attempting: n/7197.jpg
# extracted_test 6806
# Attempting: n/7198.jpg
# extracted_test 6807
# Attempting: n/7199.jpg
# extracted_test 6808
# Attempting: n/72.jpg
# extracted_test 6809
# Attempting: n/720.jpg
# extracted_test 6810
# Attempting: n/7200.jpg
# extracted_test 6811
# Attempting: n/7201.jpg
# extracted_test 6812
# Attempting: n/7202.jpg
# extracted_test 6813
# Attempting: n/7203.jpg
# extracted_test 6814
# Attempting: n/7204.jpg
# extracted_test 6815
# Attempting: n/7205.jpg
# extracted_test 6816
# Attempting: n/7206.jpg
# extracted_test 6817
# Attempting: n/7207.jpg
# extracted_test 6818
# Attempting: n/7208.jpg
# extracted_test 6819
# Attempting: n/7209.jpg
# extracted_test 6820
# Attempting: n/721.jpg
# extracted_test 6821
# Attempting: n/7210.jpg
# extracted_test 6822
# Attempting: n/7211.jpg
# extracted_test 6823
# Attempting: n/7212.jpg
# extracted_test 6824
# Attempting: n/7213.jpg
# extracted_test 6825
# Attempting: n/7214.jpg
# extracted_test 6826
# Attempting: n/7215.jpg
# extracted_test 6827
# Attempting: n/7216.jpg
# extracted_test 6828
# Attempting: n/7217.jpg
# extracted_test 6829
# Attempting: n/7218.jpg
# extracted_test 6830
# Attempting: n/7219.jpg
# extracted_test 6831
# Attempting: n/722.jpg
# extracted_test 6832
# Attempting: n/7220.jpg
# extracted_test 6833
# Attempting: n/7221.jpg
# extracted_test 6834
# Attempting: n/7222.jpg
# extracted_test 6835
# Attempting: n/7223.jpg
# extracted_test 6836
# Attempting: n/7224.jpg
# extracted_test 6837
# Attempting: n/7225.jpg
# extracted_test 6838
# Attempting: n/7226.jpg
# extracted_test 6839
# Attempting: n/7227.jpg
# extracted_test 6840
# Attempting: n/7228.jpg
# extracted_test 6841
# Attempting: n/7229.jpg
# extracted_test 6842
# Attempting: n/723.jpg
# extracted_test 6843
# Attempting: n/7230.jpg
# extracted_test 6844
# Attempting: n/7231.jpg
# extracted_test 6845
# Attempting: n/7232.jpg
# extracted_test 6846
# Attempting: n/7233.jpg
# extracted_test 6847
# Attempting: n/7234.jpg
# extracted_test 6848
# Attempting: n/7235.jpg
# extracted_test 6849
# Attempting: n/7236.jpg
# extracted_test 6850
# Attempting: n/7237.jpg
# extracted_test 6851
# Attempting: n/7238.jpg
# extracted_test 6852
# Attempting: n/7239.jpg
# extracted_test 6853
# Attempting: n/724.jpg
# extracted_test 6854
# Attempting: n/7240.jpg
# extracted_test 6855
# Attempting: n/7241.jpg
# extracted_test 6856
# Attempting: n/7242.jpg
# extracted_test 6857
# Attempting: n/7243.jpg
# extracted_test 6858
# Attempting: n/7244.jpg
# extracted_test 6859
# Attempting: n/725.jpg
# extracted_test 6860
# Attempting: n/726.jpg
# extracted_test 6861
# Attempting: n/727.jpg
# extracted_test 6862
# Attempting: n/728.jpg
# extracted_test 6863
# Attempting: n/729.jpg
# extracted_test 6864
# Attempting: n/73.jpg
# extracted_test 6865
# Attempting: n/730.jpg
# extracted_test 6866
# Attempting: n/731.jpg
# extracted_test 6867
# Attempting: n/732.jpg
# extracted_test 6868
# Attempting: n/733.jpg
# extracted_test 6869
# Attempting: n/734.jpg
# extracted_test 6870
# Attempting: n/735.jpg
# extracted_test 6871
# Attempting: n/736.jpg
# extracted_test 6872
# Attempting: n/737.jpg
# extracted_test 6873
# Attempting: n/738.jpg
# extracted_test 6874
# Attempting: n/739.jpg
# extracted_test 6875
# Attempting: n/74.jpg
# extracted_test 6876
# Attempting: n/740.jpg
# extracted_test 6877
# Attempting: n/741.jpg
# extracted_test 6878
# Attempting: n/742.jpg
# extracted_test 6879
# Attempting: n/743.jpg
# extracted_test 6880
# Attempting: n/744.jpg
# extracted_test 6881
# Attempting: n/745.jpg
# extracted_test 6882
# Attempting: n/746.jpg
# extracted_test 6883
# Attempting: n/747.jpg
# extracted_test 6884
# Attempting: n/748.jpg
# extracted_test 6885
# Attempting: n/749.jpg
# extracted_test 6886
# Attempting: n/75.jpg
# extracted_test 6887
# Attempting: n/750.jpg
# extracted_test 6888
# Attempting: n/751.jpg
# extracted_test 6889
# Attempting: n/752.jpg
# extracted_test 6890
# Attempting: n/753.jpg
# extracted_test 6891
# Attempting: n/754.jpg
# extracted_test 6892
# Attempting: n/755.jpg
# extracted_test 6893
# Attempting: n/756.jpg
# extracted_test 6894
# Attempting: n/757.jpg
# extracted_test 6895
# Attempting: n/758.jpg
# extracted_test 6896
# Attempting: n/759.jpg
# extracted_test 6897
# Attempting: n/76.jpg
# extracted_test 6898
# Attempting: n/760.jpg
# extracted_test 6899
# Attempting: n/761.jpg
# extracted_test 6900
# Attempting: n/762.jpg
# extracted_test 6901
# Attempting: n/763.jpg
# extracted_test 6902
# Attempting: n/764.jpg
# extracted_test 6903
# Attempting: n/765.jpg
# extracted_test 6904
# Attempting: n/766.jpg
# extracted_test 6905
# Attempting: n/767.jpg
# extracted_test 6906
# Attempting: n/768.jpg
# extracted_test 6907
# Attempting: n/769.jpg
# extracted_test 6908
# Attempting: n/77.jpg
# extracted_test 6909
# Attempting: n/770.jpg
# extracted_test 6910
# Attempting: n/771.jpg
# extracted_test 6911
# Attempting: n/772.jpg
# extracted_test 6912
# Attempting: n/773.jpg
# extracted_test 6913
# Attempting: n/774.jpg
# extracted_test 6914
# Attempting: n/775.jpg
# extracted_test 6915
# Attempting: n/776.jpg
# extracted_test 6916
# Attempting: n/777.jpg
# extracted_test 6917
# Attempting: n/778.jpg
# extracted_test 6918
# Attempting: n/779.jpg
# extracted_test 6919
# Attempting: n/78.jpg
# extracted_test 6920
# Attempting: n/780.jpg
# extracted_test 6921
# Attempting: n/781.jpg
# extracted_test 6922
# Attempting: n/782.jpg
# extracted_test 6923
# Attempting: n/783.jpg
# extracted_test 6924
# Attempting: n/784.jpg
# extracted_test 6925
# Attempting: n/785.jpg
# extracted_test 6926
# Attempting: n/786.jpg
# extracted_test 6927
# Attempting: n/787.jpg
# extracted_test 6928
# Attempting: n/788.jpg
# extracted_test 6929
# Attempting: n/789.jpg
# extracted_test 6930
# Attempting: n/79.jpg
# extracted_test 6931
# Attempting: n/790.jpg
# extracted_test 6932
# Attempting: n/791.jpg
# extracted_test 6933
# Attempting: n/792.jpg
# extracted_test 6934
# Attempting: n/793.jpg
# extracted_test 6935
# Attempting: n/794.jpg
# extracted_test 6936
# Attempting: n/795.jpg
# extracted_test 6937
# Attempting: n/796.jpg
# extracted_test 6938
# Attempting: n/797.jpg
# extracted_test 6939
# Attempting: n/798.jpg
# extracted_test 6940
# Attempting: n/799.jpg
# extracted_test 6941
# Attempting: n/8.jpg
# extracted_test 6942
# Attempting: n/80.jpg
# extracted_test 6943
# Attempting: n/800.jpg
# extracted_test 6944
# Attempting: n/801.jpg
# extracted_test 6945
# Attempting: n/802.jpg
# extracted_test 6946
# Attempting: n/803.jpg
# extracted_test 6947
# Attempting: n/804.jpg
# extracted_test 6948
# Attempting: n/805.jpg
# extracted_test 6949
# Attempting: n/806.jpg
# extracted_test 6950
# Attempting: n/807.jpg
# extracted_test 6951
# Attempting: n/808.jpg
# extracted_test 6952
# Attempting: n/809.jpg
# extracted_test 6953
# Attempting: n/81.jpg
# extracted_test 6954
# Attempting: n/810.jpg
# extracted_test 6955
# Attempting: n/811.jpg
# extracted_test 6956
# Attempting: n/812.jpg
# extracted_test 6957
# Attempting: n/813.jpg
# extracted_test 6958
# Attempting: n/814.jpg
# extracted_test 6959
# Attempting: n/815.jpg
# extracted_test 6960
# Attempting: n/816.jpg
# extracted_test 6961
# Attempting: n/817.jpg
# extracted_test 6962
# Attempting: n/818.jpg
# extracted_test 6963
# Attempting: n/819.jpg
# extracted_test 6964
# Attempting: n/82.jpg
# extracted_test 6965
# Attempting: n/820.jpg
# extracted_test 6966
# Attempting: n/821.jpg
# extracted_test 6967
# Attempting: n/822.jpg
# extracted_test 6968
# Attempting: n/823.jpg
# extracted_test 6969
# Attempting: n/824.jpg
# extracted_test 6970
# Attempting: n/825.jpg
# extracted_test 6971
# Attempting: n/826.jpg
# extracted_test 6972
# Attempting: n/827.jpg
# extracted_test 6973
# Attempting: n/828.jpg
# extracted_test 6974
# Attempting: n/829.jpg
# extracted_test 6975
# Attempting: n/83.jpg
# extracted_test 6976
# Attempting: n/830.jpg
# extracted_test 6977
# Attempting: n/831.jpg
# extracted_test 6978
# Attempting: n/832.jpg
# extracted_test 6979
# Attempting: n/833.jpg
# extracted_test 6980
# Attempting: n/834.jpg
# extracted_test 6981
# Attempting: n/835.jpg
# extracted_test 6982
# Attempting: n/836.jpg
# extracted_test 6983
# Attempting: n/837.jpg
# extracted_test 6984
# Attempting: n/838.jpg
# extracted_test 6985
# Attempting: n/839.jpg
# extracted_test 6986
# Attempting: n/84.jpg
# extracted_test 6987
# Attempting: n/840.jpg
# extracted_test 6988
# Attempting: n/841.jpg
# extracted_test 6989
# Attempting: n/842.jpg
# extracted_test 6990
# Attempting: n/843.jpg
# extracted_test 6991
# Attempting: n/844.jpg
# extracted_test 6992
# Attempting: n/845.jpg
# extracted_test 6993
# Attempting: n/846.jpg
# extracted_test 6994
# Attempting: n/847.jpg
# extracted_test 6995
# Attempting: n/848.jpg
# extracted_test 6996
# Attempting: n/849.jpg
# extracted_test 6997
# Attempting: n/85.jpg
# extracted_test 6998
# Attempting: n/850.jpg
# extracted_test 6999
# Attempting: n/851.jpg
# extracted_test 7000
# Attempting: n/852.jpg
# extracted_test 7001
# Attempting: n/853.jpg
# extracted_test 7002
# Attempting: n/854.jpg
# extracted_test 7003
# Attempting: n/855.jpg
# extracted_test 7004
# Attempting: n/856.jpg
# extracted_test 7005
# Attempting: n/857.jpg
# extracted_test 7006
# Attempting: n/858.jpg
# extracted_test 7007
# Attempting: n/859.jpg
# extracted_test 7008
# Attempting: n/86.jpg
# extracted_test 7009
# Attempting: n/860.jpg
# extracted_test 7010
# Attempting: n/861.jpg
# extracted_test 7011
# Attempting: n/862.jpg
# extracted_test 7012
# Attempting: n/863.jpg
# extracted_test 7013
# Attempting: n/864.jpg
# extracted_test 7014
# Attempting: n/865.jpg
# extracted_test 7015
# Attempting: n/866.jpg
# extracted_test 7016
# Attempting: n/867.jpg
# extracted_test 7017
# Attempting: n/868.jpg
# extracted_test 7018
# Attempting: n/869.jpg
# extracted_test 7019
# Attempting: n/87.jpg
# extracted_test 7020
# Attempting: n/870.jpg
# extracted_test 7021
# Attempting: n/871.jpg
# extracted_test 7022
# Attempting: n/872.jpg
# extracted_test 7023
# Attempting: n/873.jpg
# extracted_test 7024
# Attempting: n/874.jpg
# extracted_test 7025
# Attempting: n/875.jpg
# extracted_test 7026
# Attempting: n/876.jpg
# extracted_test 7027
# Attempting: n/877.jpg
# extracted_test 7028
# Attempting: n/878.jpg
# extracted_test 7029
# Attempting: n/879.jpg
# extracted_test 7030
# Attempting: n/88.jpg
# extracted_test 7031
# Attempting: n/880.jpg
# extracted_test 7032
# Attempting: n/881.jpg
# extracted_test 7033
# Attempting: n/882.jpg
# extracted_test 7034
# Attempting: n/883.jpg
# extracted_test 7035
# Attempting: n/884.jpg
# extracted_test 7036
# Attempting: n/885.jpg
# extracted_test 7037
# Attempting: n/886.jpg
# extracted_test 7038
# Attempting: n/887.jpg
# extracted_test 7039
# Attempting: n/888.jpg
# extracted_test 7040
# Attempting: n/889.jpg
# extracted_test 7041
# Attempting: n/89.jpg
# extracted_test 7042
# Attempting: n/890.jpg
# extracted_test 7043
# Attempting: n/891.jpg
# extracted_test 7044
# Attempting: n/892.jpg
# extracted_test 7045
# Attempting: n/893.jpg
# extracted_test 7046
# Attempting: n/894.jpg
# extracted_test 7047
# Attempting: n/895.jpg
# extracted_test 7048
# Attempting: n/896.jpg
# extracted_test 7049
# Attempting: n/897.jpg
# extracted_test 7050
# Attempting: n/898.jpg
# extracted_test 7051
# Attempting: n/899.jpg
# extracted_test 7052
# Attempting: n/9.jpg
# extracted_test 7053
# Attempting: n/90.jpg
# extracted_test 7054
# Attempting: n/900.jpg
# extracted_test 7055
# Attempting: n/901.jpg
# extracted_test 7056
# Attempting: n/902.jpg
# extracted_test 7057
# Attempting: n/903.jpg
# extracted_test 7058
# Attempting: n/904.jpg
# extracted_test 7059
# Attempting: n/905.jpg
# extracted_test 7060
# Attempting: n/906.jpg
# extracted_test 7061
# Attempting: n/907.jpg
# extracted_test 7062
# Attempting: n/908.jpg
# extracted_test 7063
# Attempting: n/909.jpg
# extracted_test 7064
# Attempting: n/91.jpg
# extracted_test 7065
# Attempting: n/910.jpg
# extracted_test 7066
# Attempting: n/911.jpg
# extracted_test 7067
# Attempting: n/912.jpg
# extracted_test 7068
# Attempting: n/913.jpg
# extracted_test 7069
# Attempting: n/914.jpg
# extracted_test 7070
# Attempting: n/915.jpg
# extracted_test 7071
# Attempting: n/916.jpg
# extracted_test 7072
# Attempting: n/917.jpg
# extracted_test 7073
# Attempting: n/918.jpg
# extracted_test 7074
# Attempting: n/919.jpg
# extracted_test 7075
# Attempting: n/92.jpg
# extracted_test 7076
# Attempting: n/920.jpg
# extracted_test 7077
# Attempting: n/921.jpg
# extracted_test 7078
# Attempting: n/922.jpg
# extracted_test 7079
# Attempting: n/923.jpg
# extracted_test 7080
# Attempting: n/924.jpg
# extracted_test 7081
# Attempting: n/925.jpg
# extracted_test 7082
# Attempting: n/926.jpg
# extracted_test 7083
# Attempting: n/927.jpg
# extracted_test 7084
# Attempting: n/928.jpg
# extracted_test 7085
# Attempting: n/929.jpg
# extracted_test 7086
# Attempting: n/93.jpg
# extracted_test 7087
# Attempting: n/930.jpg
# extracted_test 7088
# Attempting: n/931.jpg
# extracted_test 7089
# Attempting: n/932.jpg
# extracted_test 7090
# Attempting: n/933.jpg
# extracted_test 7091
# Attempting: n/934.jpg
# extracted_test 7092
# Attempting: n/935.jpg
# extracted_test 7093
# Attempting: n/936.jpg
# extracted_test 7094
# Attempting: n/937.jpg
# extracted_test 7095
# Attempting: n/938.jpg
# extracted_test 7096
# Attempting: n/939.jpg
# extracted_test 7097
# Attempting: n/94.jpg
# extracted_test 7098
# Attempting: n/940.jpg
# extracted_test 7099
# Attempting: n/941.jpg
# extracted_test 7100
# Attempting: n/942.jpg
# extracted_test 7101
# Attempting: n/943.jpg
# extracted_test 7102
# Attempting: n/944.jpg
# extracted_test 7103
# Attempting: n/945.jpg
# extracted_test 7104
# Attempting: n/946.jpg
# extracted_test 7105
# Attempting: n/947.jpg
# extracted_test 7106
# Attempting: n/948.jpg
# extracted_test 7107
# Attempting: n/949.jpg
# extracted_test 7108
# Attempting: n/95.jpg
# extracted_test 7109
# Attempting: n/950.jpg
# extracted_test 7110
# Attempting: n/951.jpg
# extracted_test 7111
# Attempting: n/952.jpg
# extracted_test 7112
# Attempting: n/953.jpg
# extracted_test 7113
# Attempting: n/954.jpg
# extracted_test 7114
# Attempting: n/955.jpg
# extracted_test 7115
# Attempting: n/956.jpg
# extracted_test 7116
# Attempting: n/957.jpg
# extracted_test 7117
# Attempting: n/958.jpg
# extracted_test 7118
# Attempting: n/959.jpg
# extracted_test 7119

# %%
df=pd.concat(dfl)
len(df)
# Out:
# 7119

# %%
functions.extract_from_image('n/1217.jpg')

# %%
with open(r'data/text_full.txt', 'w',encoding="utf-8") as fp:
    for item in texts:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
for i in df.columns:
    print("The VALUES of "+ i + str(df[i].isna().value_counts()))
# Out:
# The VALUES of ZipcodeTrue     3602
# False    3517
# Name: Zipcode, dtype: int64
# The VALUES of LatitudeTrue     5729
# False    1390
# Name: Latitude, dtype: int64
# The VALUES of LongitudeTrue     5729
# False    1390
# Name: Longitude, dtype: int64
# The VALUES of AddressTrue     5832
# False    1287
# Name: Address, dtype: int64
# The VALUES of pricesTrue     5132
# False    1987
# Name: prices, dtype: int64
# The VALUES of timeTrue     4664
# False    2455
# Name: time, dtype: int64

# %%
dfm = pd.DataFrame(texts)

# %%
dfm["c"]=1

# %%
dfm.to_csv(r"data\final_raw.csv")

# %%
df.to_csv(r"data\final_structured.csv")

# %%
import run
# Out:
# hello

# %%
run.run()
# Out:
# would you like to use your camera? y/n  y
#    Zipcode  Latitude  Longitude  Address  prices  time  Store Names
# 0      NaN       NaN        NaN      NaN     NaN   NaN          NaN

# %%
images/large-receipt-image-dataset-SRD/1007-receipt.jpg
